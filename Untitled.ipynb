# %%
AllRuns = [48741,49854]
maskFileName=[
'snap49870msk.xml',
'snap48741msk.xml']

# %%
from mantid.simpleapi import *
import FocDACUtilities as DAC
import SNAP_InstPrm as iPrm 
import importlib
importlib.reload(DAC)
importlib.reload(iPrm)

cleanUp = True
GSASOut = False  

########################################
# MAIN Workflow
#######################################
 
#maskFileName='snap49870_8x8_binMskInfo.json'
calibState = 'before' #describes whether calibration was conducted before or after sample runs

for runidx,run in enumerate(AllRuns):

  #initialise reduction parameters happens for every run
  rPrm = DAC.initPrm(run,calibState)
  if len(maskFileName)==1:
    rPrm['maskFileName']=maskFileName[0]
  else:
    rPrm['maskFileName']=maskFileName[runidx]
    

  #if state hasn't been initialised, initialise state reduction parameters and load raw VCorr
  if runidx == 0:

    sPrm = DAC.getStatePrm(run,calibState)

    LoadNexus(Filename=iPrm.stateLoc + sPrm['stateID'] + '/' + sPrm['rawVCorrFileName'],
    OutputWorkspace='TOF_rawVmB')

    DAC.setupStateGrouping(sPrm)

  #also reinitialise if state changes 
  if DAC.checkStateChange(run,sPrm):

    sPrm = DAC.getStatePrm(run,calibState)

    LoadNexus(Filename=iPrm.stateLoc + sPrm['stateID'] + '/' + sPrm['rawVCorrFileName'],
    OutputWorkspace='TOF_rawVmB')

    DAC.setupStateGrouping(sPrm)

  TOF_runWS = DAC.preProcSNAP(run,rPrm,sPrm)  
  gpString = TOF_runWS + '_monitors' #a list of all ws to group
  
  #masking
  
  TOF_runWS_msk,mskTag = DAC.SNAPMsk(TOF_runWS,rPrm,sPrm) #mask run workspace
  TOF_rawVmB_msk,mskTag = DAC.SNAPMsk('TOF_rawVmB',rPrm,sPrm)

  #convert to d-spacing

  DSpac_runWS_msk = f'DSpac_{run}_{mskTag}'
  ConvertUnits(InputWorkspace=TOF_runWS_msk,
  OutputWorkspace=DSpac_runWS_msk,
  Target='dSpacing',
  EMode='Elastic',
  ConvertFromPointData=True)

  DSpac_VmB_msk = f'DSpac_rawVmB_{mskTag}'
  ConvertUnits(InputWorkspace=TOF_rawVmB_msk,
  OutputWorkspace=f'DSpac_rawVmB_{mskTag}',
  Target='dSpacing',
  EMode='Elastic',
  ConvertFromPointData=True)

  #Focus the data and vanadium using DiffractionFocusing for each of requested groups
  
  for gpNo, focGrp in enumerate(sPrm['focGroupLst']):
    DiffractionFocussing(InputWorkspace=DSpac_runWS_msk,
    OutputWorkspace=f'{DSpac_runWS_msk}_{focGrp}',
    GroupingWorkspace=f'SNAP{focGrp}Gp')

    DiffractionFocussing(InputWorkspace=f'DSpac_rawVmB_{mskTag}',
    OutputWorkspace=f'DSpac_rawVmB_{mskTag}_{focGrp}',
    GroupingWorkspace=f'SNAP{focGrp}Gp')

    #make vanadium correction (complicated by mystery peaks)
    #(n.b. also no attenuation correction on V, but none on data either, this isn't quantatative)
    #Minus(LHSWorkspace=f'd{VRun}_{wstag}_d6', RHSWorkspace=f'd{VBRun}_{wstag}_d6', OutputWorkspace=f'dVmB_{wstag}')
    StripPeaks(InputWorkspace=f'DSpac_rawVmB_{mskTag}_{focGrp}',
    OutputWorkspace=f'DSpac_rawVmB_{mskTag}_{focGrp}_strp',
    FWHM=2, 
    PeakPositions='1.22,2.04,2.11,2.19', 
    BackgroundType='Quadratic')
    
    SmoothData(InputWorkspace=f'DSpac_rawVmB_{mskTag}_{focGrp}_strp', 
    OutputWorkspace=f'DSpac_VCorr_{mskTag}_{focGrp}',
    NPoints='9')

#Apply vanadium correction, and trim to usable limits

    Divide(LHSWorkspace=f'{DSpac_runWS_msk}_{focGrp}', 
    RHSWorkspace=f'DSpac_VCorr_{mskTag}_{focGrp}', 
    OutputWorkspace=f'{DSpac_runWS_msk}_{focGrp}_V')

    Rebin(InputWorkspace=f'{DSpac_runWS_msk}_{focGrp}_V', 
    OutputWorkspace=f'{DSpac_runWS_msk}_{focGrp}_VR',
    Params='0.5,-0.001,4.5', PreserveEvents=False)

    CropWorkspaceRagged(InputWorkspace=f'{DSpac_runWS_msk}_{focGrp}_VR', 
    OutputWorkspace=f'{DSpac_runWS_msk}_{focGrp}_VRT', 
    XMin=sPrm['focGroupDMin'][gpNo], 
    XMax=sPrm['focGroupDMax'][gpNo])

    gpString = gpString+ f',{DSpac_runWS_msk}_{focGrp}_VRT'

    if cleanUp:
        DeleteWorkspaces(WorkspaceList=f'DSpac_rawVmB_{mskTag}_{focGrp},'\
        f'DSpac_rawVmB_{mskTag}_{focGrp}_strp,'
        f'DSpac_VCorr_{mskTag}_{focGrp},'
        f'{DSpac_runWS_msk}_{focGrp},'
        f'{DSpac_runWS_msk}_{focGrp}_V,'
        f'{DSpac_runWS_msk}_{focGrp}_VR')    
    
  GroupWorkspaces(InputWorkspaces=gpString,
      OutputWorkspace=f'SNAP{run}_Red')

  if cleanUp:      
    DeleteWorkspaces(WorkspaceList=TOF_runWS_msk + \
    ','+TOF_runWS+\
    f',DSpac_rawVmB_{mskTag},'\
    f'DSpac_{run}_{mskTag}'    
    ) 
  

if cleanUp:
  DeleteWorkspaces(WorkspaceList=TOF_rawVmB_msk)

print('SNAPRed complete')
  #Group workspaces according to run number
#GroupWorkspaces(GlobExpression=str(run))
# Out:
# ConfigService-[Information] Unable to locate directory at: /etc/mantid/instrument
# ConfigService-[Information] This is Mantid version 6.2.0 revision gbf806d7983f
# ConfigService-[Information] running on analysis-node19.sns.gov starting 2022-08-05T18:13Z
# ConfigService-[Information] Properties file(s) loaded: /SNS/users/66j/miniconda3/envs/scippneutron/bin/Mantid.properties, /etc/mantid.local.properties, /SNS/users/66j/.mantid/Mantid.user.properties
# ConfigService-[Information] Unable to locate directory at: /etc/mantid/instrument
# FrameworkManager-[Notice] Welcome to Mantid 6.2.0
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid6.2
# FrameworkManager-[Information] Version check disabled.
# GitHubApiHelper-[Information] Making unauthenticated calls to GitHub
# GitHubApiHelper-[Information] Making unauthenticated calls to GitHub
# DownloadInstrument-[Notice] All instrument definitions up to date
# GetIPTS-[Notice] GetIPTS started
# GetIPTS-[Information] Algorithm: GetIPTS v1
# GetIPTS-[Information] Execution Date: 2022-08-05 18:13:07.380133000
# GetIPTS-[Information] Execution Duration: -1 seconds
# GetIPTS-[Information] UUID: ace1eeb8-5f3a-4cbd-9569-83d0dae8cf7e
# GetIPTS-[Information] Parameters:
# GetIPTS-[Information]   Name: RunNumber, Value: 48741, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Directory, Value: , Default?: Yes, Direction: Output
# GetIPTS-[Information] Looking for 'SNAP_48741'
# FileFinder-[Information] found path = /SNS/SNAP/IPTS-24179/nexus/SNAP_48741.nxs.h5
# GetIPTS-[Notice] IPTS directory is: /SNS/SNAP/IPTS-24179/
# GetIPTS-[Notice] GetIPTS successful, Duration 0.13 seconds
# GetIPTS-[Notice] GetIPTS started
# GetIPTS-[Information] Algorithm: GetIPTS v1
# GetIPTS-[Information] Execution Date: 2022-08-05 18:13:07.512728000
# GetIPTS-[Information] Execution Duration: -1 seconds
# GetIPTS-[Information] UUID: 4e611269-64c0-4e54-9aaa-471643d385f3
# GetIPTS-[Information] Parameters:
# GetIPTS-[Information]   Name: RunNumber, Value: 48741, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Directory, Value: , Default?: Yes, Direction: Output
# GetIPTS-[Information] Looking for 'SNAP_48741'
# FileFinder-[Information] found path = /SNS/SNAP/IPTS-24179/nexus/SNAP_48741.nxs.h5
# /SNS/SNAP/IPTS-24179/nexus//SNAP_48741.nxs.h5GetIPTS-[Notice] IPTS directory is: /SNS/SNAP/IPTS-24179/
# GetIPTS-[Notice] GetIPTS successful, Duration 0.05 seconds
#
# successfully found calibration file:
#  /SNS/SNAP/shared/Calibration/14100-10/SNAPcalibLog48705.json
# LoadNexus-[Notice] LoadNexus started
# LoadNexus-[Information] Algorithm: LoadNexus v1
# LoadNexus-[Information] Execution Date: 2022-08-05 18:13:07.868024000
# LoadNexus-[Information] Execution Duration: -1 seconds
# LoadNexus-[Information] UUID: e2fd217d-52d1-4d2a-b3ba-d8cade97bde2
# LoadNexus-[Information] Parameters:
# LoadNexus-[Information]   Name: Filename, Value: /SNS/SNAP/shared/ ... -10/RVMB48707.nxs, Default?: No, Direction: Input
# LoadNexus-[Information]   Name: OutputWorkspace, Value: TOF_rawVmB, Default?: No, Direction: Output
# LoadNexus-[Information]   Name: SpectrumMin, Value: 1, Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: SpectrumMax, Value: 2147483647, Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: SpectrumList, Value: , Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: EntryNumber, Value: 0, Default?: Yes, Direction: Input
# InstrumentDefinitionParser-[Information] Loading geometry cache from /SNS/users/66j/.mantid/instrument/geometryCache/SNAP1d6954627f1f0a3b3d8ee736fe69593ddb25bfb6.vtp
# ISISRunLogs-[Warning] Cannot find period log. Logs will be not be filtered by current period
# ISISRunLogs-[Warning] Cannot find periods log. Logs will be not be filtered by current period
# LoadNexus-[Notice] LoadNexus successful, Duration 17.86 seconds
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace started
# CreateGroupingWorkspace-[Information] Algorithm: CreateGroupingWorkspace v1
# CreateGroupingWorkspace-[Information] Execution Date: 2022-08-05 18:13:25.734348000
# CreateGroupingWorkspace-[Information] Execution Duration: -1 seconds
# CreateGroupingWorkspace-[Information] UUID: 7254a94d-2c4e-47ac-a84e-e6c426fb7707
# CreateGroupingWorkspace-[Information] Parameters:
# CreateGroupingWorkspace-[Information]   Name: InputWorkspace, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentName, Value: SNAP, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OldCalFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupNames, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupDetectorsBy, Value: Column, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: MaxRecursionDepth, Value: 5, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: FixedGroupCount, Value: 0, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: CustomGroupingString, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: ComponentName, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OutputWorkspace, Value: SNAPColumnGp, Default?: No, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupedSpectraResult, Value: 2147483647, Default?: Yes, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupsResult, Value: 2147483647, Default?: Yes, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# CreateGroupingWorkspace-[Information] 1179648 entries in the detectorID-to-group map.
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace successful, Duration 3.19 seconds
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace started
# CreateGroupingWorkspace-[Information] Algorithm: CreateGroupingWorkspace v1
# CreateGroupingWorkspace-[Information] Execution Date: 2022-08-05 18:13:28.942920000
# CreateGroupingWorkspace-[Information] Execution Duration: -1 seconds
# CreateGroupingWorkspace-[Information] UUID: 01e46e1d-1b02-4dc3-9758-7d0ddddd5514
# CreateGroupingWorkspace-[Information] Parameters:
# CreateGroupingWorkspace-[Information]   Name: InputWorkspace, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentName, Value: SNAP, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OldCalFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupNames, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupDetectorsBy, Value: All, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: MaxRecursionDepth, Value: 5, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: FixedGroupCount, Value: 0, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: CustomGroupingString, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: ComponentName, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OutputWorkspace, Value: SNAPAllGp, Default?: No, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupedSpectraResult, Value: 2147483647, Default?: Yes, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupsResult, Value: 2147483647, Default?: Yes, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# CreateGroupingWorkspace-[Information] 1179650 entries in the detectorID-to-group map.
# CreateGroupingWorkspace-[Warning] 2 detector IDs (out of 1179650) were not found in the instrument
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace successful, Duration 3.43 seconds
# State groups initialisedGroupWorkspaces-[Notice] GroupWorkspaces started
# GroupWorkspaces-[Information] Algorithm: GroupWorkspaces v1
# GroupWorkspaces-[Information] Execution Date: 2022-08-05 18:13:32.396566000
# GroupWorkspaces-[Information] Execution Duration: -1 seconds
# GroupWorkspaces-[Information] UUID: 43425eb5-87f9-4902-a09b-f2512ceb9e25
# GroupWorkspaces-[Information] Parameters:
# GroupWorkspaces-[Information]   Name: InputWorkspaces, Value: TOF_rawVmB,SNAPColumnGp,SNAPAllGp, Default?: No, Direction: Input
# GroupWorkspaces-[Information]   Name: GlobExpression, Value: , Default?: Yes, Direction: Input
# GroupWorkspaces-[Information]   Name: OutputWorkspace, Value: CommonRed, Default?: No, Direction: Output
# GroupWorkspaces-[Notice] GroupWorkspaces successful, Duration 0.00 seconds
#
# GetIPTS-[Notice] GetIPTS started
# GetIPTS-[Information] Algorithm: GetIPTS v1
# GetIPTS-[Information] Execution Date: 2022-08-05 18:13:32.398327000
# GetIPTS-[Information] Execution Duration: -1 seconds
# GetIPTS-[Information] UUID: 5fce70e1-fed6-4532-8c56-1a1f0c185043
# GetIPTS-[Information] Parameters:
# GetIPTS-[Information]   Name: RunNumber, Value: 48741, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Directory, Value: , Default?: Yes, Direction: Output
# GetIPTS-[Information] Looking for 'SNAP_48741'
# FileFinder-[Information] found path = /SNS/SNAP/IPTS-24179/nexus/SNAP_48741.nxs.h5
# GetIPTS-[Notice] IPTS directory is: /SNS/SNAP/IPTS-24179/
# /SNS/SNAP/IPTS-24179/nexus//SNAP_48741.nxs.h5
# GetIPTS-[Notice] GetIPTS successful, Duration 0.05 seconds
# GetIPTS-[Notice] GetIPTS started
# GetIPTS-[Information] Algorithm: GetIPTS v1
# GetIPTS-[Information] Execution Date: 2022-08-05 18:13:32.684546000
# GetIPTS-[Information] Execution Duration: -1 seconds
# GetIPTS-[Information] UUID: 802a0ad3-8e0e-43e0-94a3-746693c55455
# GetIPTS-[Information] Parameters:
# GetIPTS-[Information]   Name: RunNumber, Value: 48741, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# GetIPTS-[Information]   Name: Directory, Value: , Default?: Yes, Direction: Output
# GetIPTS-[Information] Looking for 'SNAP_48741'
# FileFinder-[Information] found path = /SNS/SNAP/IPTS-24179/nexus/SNAP_48741.nxs.h5
# /SNS/SNAP/IPTS-24179/nexus//SNAP_48741.nxs.h5GetIPTS-[Notice] IPTS directory is: /SNS/SNAP/IPTS-24179/
# GetIPTS-[Notice] GetIPTS successful, Duration 0.06 seconds
#
# successfully found calibration file:
#  /SNS/SNAP/shared/Calibration/14100-10/SNAPcalibLog48705.json
# LoadNexus-[Notice] LoadNexus started
# LoadNexus-[Information] Algorithm: LoadNexus v1
# LoadNexus-[Information] Execution Date: 2022-08-05 18:13:32.783654000
# LoadNexus-[Information] Execution Duration: -1 seconds
# LoadNexus-[Information] UUID: 41b6cc5e-1021-4d53-a3fa-15122f5e59fc
# LoadNexus-[Information] Parameters:
# LoadNexus-[Information]   Name: Filename, Value: /SNS/SNAP/shared/ ... -10/RVMB48707.nxs, Default?: No, Direction: Input
# LoadNexus-[Information]   Name: OutputWorkspace, Value: TOF_rawVmB, Default?: No, Direction: Output
# LoadNexus-[Information]   Name: SpectrumMin, Value: 1, Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: SpectrumMax, Value: 2147483647, Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: SpectrumList, Value: , Default?: Yes, Direction: Input
# LoadNexus-[Information]   Name: EntryNumber, Value: 0, Default?: Yes, Direction: Input
# ISISRunLogs-[Warning] Cannot find period log. Logs will be not be filtered by current period
# ISISRunLogs-[Warning] Cannot find periods log. Logs will be not be filtered by current period
# LoadNexus-[Notice] LoadNexus successful, Duration 16.18 seconds
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace started
# CreateGroupingWorkspace-[Information] Algorithm: CreateGroupingWorkspace v1
# CreateGroupingWorkspace-[Information] Execution Date: 2022-08-05 18:13:50.389024000
# CreateGroupingWorkspace-[Information] Execution Duration: -1 seconds
# CreateGroupingWorkspace-[Information] UUID: 3ecb024a-6dc8-469b-862f-419d831417a0
# CreateGroupingWorkspace-[Information] Parameters:
# CreateGroupingWorkspace-[Information]   Name: InputWorkspace, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentName, Value: SNAP, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OldCalFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupNames, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupDetectorsBy, Value: Column, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: MaxRecursionDepth, Value: 5, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: FixedGroupCount, Value: 0, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: CustomGroupingString, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: ComponentName, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OutputWorkspace, Value: SNAPColumnGp, Default?: No, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupedSpectraResult, Value: 2147483647, Default?: Yes, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupsResult, Value: 2147483647, Default?: Yes, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# CreateGroupingWorkspace-[Information] 1179648 entries in the detectorID-to-group map.
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace successful, Duration 3.15 seconds
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace started
# CreateGroupingWorkspace-[Information] Algorithm: CreateGroupingWorkspace v1
# CreateGroupingWorkspace-[Information] Execution Date: 2022-08-05 18:13:54.238117000
# CreateGroupingWorkspace-[Information] Execution Duration: -1 seconds
# CreateGroupingWorkspace-[Information] UUID: c995cd87-e110-4fe7-8ed3-dd364761079c
# CreateGroupingWorkspace-[Information] Parameters:
# CreateGroupingWorkspace-[Information]   Name: InputWorkspace, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentName, Value: SNAP, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: InstrumentFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OldCalFilename, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupNames, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: GroupDetectorsBy, Value: All, Default?: No, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: MaxRecursionDepth, Value: 5, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: FixedGroupCount, Value: 0, Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: CustomGroupingString, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: ComponentName, Value: , Default?: Yes, Direction: Input
# CreateGroupingWorkspace-[Information]   Name: OutputWorkspace, Value: SNAPAllGp, Default?: No, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupedSpectraResult, Value: 2147483647, Default?: Yes, Direction: Output
# CreateGroupingWorkspace-[Information]   Name: NumberGroupsResult, Value: 2147483647, Default?: Yes, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# CreateGroupingWorkspace-[Information] 1179650 entries in the detectorID-to-group map.
# CreateGroupingWorkspace-[Warning] 2 detector IDs (out of 1179650) were not found in the instrument
# CreateGroupingWorkspace-[Notice] CreateGroupingWorkspace successful, Duration 3.31 seconds
# GroupWorkspaces-[Notice] GroupWorkspaces started
# GroupWorkspaces-[Information] Algorithm: GroupWorkspaces v1
# GroupWorkspaces-[Information] Execution Date: 2022-08-05 18:13:58.228970000
# State groups initialisedGroupWorkspaces-[Information] Execution Duration: -1 seconds
# GroupWorkspaces-[Information] UUID: c78aed70-f6f3-45d6-a3cf-fb5576466e3d
# GroupWorkspaces-[Information] Parameters:
# GroupWorkspaces-[Information]   Name: InputWorkspaces, Value: TOF_rawVmB,SNAPColumnGp,SNAPAllGp, Default?: No, Direction: Input
# GroupWorkspaces-[Information]   Name: GlobExpression, Value: , Default?: Yes, Direction: Input
# GroupWorkspaces-[Information]   Name: OutputWorkspace, Value: CommonRed, Default?: No, Direction: Output
# GroupWorkspaces-[Notice] GroupWorkspaces successful, Duration 0.00 seconds
#
# LoadEventNexus-[Notice] LoadEventNexus started
# LoadEventNexus-[Information] Algorithm: LoadEventNexus v1
# LoadEventNexus-[Information] Execution Date: 2022-08-05 18:13:58.232958000
# LoadEventNexus-[Information] Execution Duration: -1 seconds
# LoadEventNexus-[Information] UUID: 53ffebf1-00cb-4d73-9d41-53d73d7c15f7
# LoadEventNexus-[Information] Parameters:
# LoadEventNexus-[Information]   Name: Filename, Value: /SNS/SNAP/IPTS-24 ... SNAP_48741.nxs.h5, Default?: No, Direction: Input
# LoadEventNexus-[Information]   Name: OutputWorkspace, Value: TOF_48741, Default?: No, Direction: Output
# LoadEventNexus-[Information]   Name: NXentryName, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterByTofMin, Value: 2350, Default?: No, Direction: Input
# LoadEventNexus-[Information]   Name: FilterByTofMax, Value: 14750, Default?: No, Direction: Input
# LoadEventNexus-[Information]   Name: FilterByTimeStart, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterByTimeStop, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: BankName, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: SingleBankPixelsOnly, Value: 1, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: Precount, Value: 1, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: CompressTolerance, Value: -1, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: ChunkNumber, Value: 2147483647, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: TotalChunks, Value: 2147483647, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: LoadMonitors, Value: 1, Default?: No, Direction: Input
# LoadEventNexus-[Information]   Name: MonitorsLoadOnly, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterMonByTofMin, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterMonByTofMax, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterMonByTimeStart, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: FilterMonByTimeStop, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: SpectrumMin, Value: 2147483647, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: SpectrumMax, Value: 2147483647, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: SpectrumList, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: MetaDataOnly, Value: 0, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: LoadLogs, Value: 1, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: LoadType, Value: Default, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: LoadNexusInstrumentXML, Value: 1, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: NumberOfBins, Value: 500, Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: AllowList, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information]   Name: BlockList, Value: , Default?: Yes, Direction: Input
# LoadEventNexus-[Information] Loading logs from NeXus file...
# LogParser-[Warning] Cannot process ICPevent log. Period 1 assumed for all data.
# ExperimentInfo-[Information] Parameter map entry missing from NeXus file. Continuing without it.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# LoadIDFFromNexus-[Notice] Instrument parameter file: /SNS/users/66j/.mantid/instrument/SNAP_Parameters.xml has been loaded.
# LoadIDFFromNexus-[Notice]
# LoadIDFFromNexus-[Notice] No correction parameter file applies to the date for correction file.
# LoadEventNexus-[Information] Read 14781628 events. Shortest TOF: 2350 microsec; longest TOF: 14750 microsec.
# LoadEventNexus-[Information] Loading monitors from NeXus file...
# LoadEventNexus-[Information] New workspace name for monitors: TOF_48741_monitors
# LoadNexusMonitors-[Information] Loading monitor1
# LoadNexusMonitors-[Information] Loading monitor2
# LoadNexusMonitors-[Information] Loading logs from NeXus file...
# ExperimentInfo-[Information] Parameter map entry missing from NeXus file. Continuing without it.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# LoadIDFFromNexus-[Notice] Instrument parameter file: /SNS/users/66j/.mantid/instrument/SNAP_Parameters.xml has been loaded.
# LoadIDFFromNexus-[Notice]
# LoadIDFFromNexus-[Notice] No correction parameter file applies to the date for correction file.
# LoadEventNexus-[Notice] LoadEventNexus successful, Duration 9.42 seconds
# NormaliseByCurrent-[Notice] NormaliseByCurrent started
# NormaliseByCurrent-[Information] Algorithm: NormaliseByCurrent v1
# NormaliseByCurrent-[Information] Execution Date: 2022-08-05 18:14:07.657577000
# NormaliseByCurrent-[Information] Execution Duration: -1 seconds
# NormaliseByCurrent-[Information] UUID: 00d9fc24-3b4f-4478-874b-72454f2a3af4
# NormaliseByCurrent-[Information] Parameters:
# NormaliseByCurrent-[Information]   Name: InputWorkspace, Value: TOF_48741, Default?: No, Direction: Input
# NormaliseByCurrent-[Information]   Name: OutputWorkspace, Value: TOF_48741, Default?: No, Direction: Output
# NormaliseByCurrent-[Information]   Name: RecalculatePCharge, Value: 0, Default?: Yes, Direction: Input
# NormaliseByCurrent-[Information] No nperiods property. If this is multi-period data, then you will be normalising against the wrong current.
# NormaliseByCurrent-[Information] Normalisation current: 3513.52 uamps
# NormaliseByCurrent-[Notice] NormaliseByCurrent successful, Duration 1.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Information] Algorithm: CompressEvents v1
# CompressEvents-[Information] Execution Date: 2022-08-05 18:14:09.267400000
# CompressEvents-[Information] Execution Duration: -1 seconds
# CompressEvents-[Information] UUID: 8b479f40-c520-4ecc-81f3-544de2e65fb0
# CompressEvents-[Information] Parameters:
# CompressEvents-[Information]   Name: InputWorkspace, Value: TOF_48741, Default?: No, Direction: Input
# CompressEvents-[Information]   Name: OutputWorkspace, Value: TOF_48741, Default?: No, Direction: Output
# CompressEvents-[Information]   Name: Tolerance, Value: 1.0000000000000001e-05, Default?: Yes, Direction: Input
# CompressEvents-[Information]   Name: WallClockTolerance, Value: 60, Default?: No, Direction: Input
# CompressEvents-[Information]   Name: StartTime, Value: , Default?: Yes, Direction: Input
# CompressEvents-[Notice] CompressEvents successful, Duration 0.85 seconds
# ApplyDiffCal-[Notice] ApplyDiffCal started
# ApplyDiffCal-[Information] Algorithm: ApplyDiffCal v1
# ApplyDiffCal-[Information] Execution Date: 2022-08-05 18:14:10.114901000
# ApplyDiffCal-[Information] Execution Duration: -1 seconds
# ApplyDiffCal-[Information] UUID: a0822825-9ec8-4dd5-9312-37092c844f01
# ApplyDiffCal-[Information] Parameters:
# ApplyDiffCal-[Information]   Name: InstrumentWorkspace, Value: TOF_48741, Default?: No, Direction: InOut
# ApplyDiffCal-[Information]   Name: CalibrationFile, Value: /SNS/SNAP/shared/ ... _geom_20220805.h5, Default?: No, Direction: Input
# ApplyDiffCal-[Information]   Name: CalibrationWorkspace, Value: , Default?: Yes, Direction: Input
# ApplyDiffCal-[Information]   Name: OffsetsWorkspace, Value: , Default?: Yes, Direction: Input
# ApplyDiffCal-[Information]   Name: ClearCalibration, Value: 0, Default?: Yes, Direction: Input
# H5Util-[Information] Failed to open dataset "dasid"
#
# H5Util-[Information] Failed to open dataset "offset"
#
# LoadDiffCal-[Information] Not loading GroupingWorkspace from the calibration file
# LoadDiffCal-[Information] Not making a MaskWorkspace
# ApplyDiffCal-[Notice] ApplyDiffCal successful, Duration 6.61 seconds
# SumNeighbours-[Notice] SumNeighbours started
# SumNeighbours-[Information] Algorithm: SumNeighbours v1
# SumNeighbours-[Information] Execution Date: 2022-08-05 18:14:16.726703000
# SumNeighbours-[Information] Execution Duration: -1 seconds
# SumNeighbours-[Information] UUID: 97f779ac-14e1-4829-9515-f66674135189
# SumNeighbours-[Information] Parameters:
# SumNeighbours-[Information]   Name: InputWorkspace, Value: TOF_48741, Default?: No, Direction: Input
# SumNeighbours-[Information]   Name: OutputWorkspace, Value: TOF_48741, Default?: No, Direction: Output
# SumNeighbours-[Information]   Name: SumX, Value: 8, Default?: No, Direction: Input
# SumNeighbours-[Information]   Name: SumY, Value: 8, Default?: No, Direction: Input
# SmoothNeighbours-[Information] Smoothing with Flat Weighting
# SumNeighbours-[Notice] SumNeighbours successful, Duration 4.47 seconds
# LoadMask-[Notice] LoadMask started
# LoadMask-[Information] Algorithm: LoadMask v1
# LoadMask-[Information] Execution Date: 2022-08-05 18:14:22.799314000
# LoadMask-[Information] Execution Duration: -1 seconds
# LoadMask-[Information] UUID: 87e577f5-4c78-48e8-87da-557d15573ed4
# LoadMask-[Information] Parameters:
# LoadMask-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# LoadMask-[Information]   Name: InputFile, Value: /SNS/SNAP/IPTS-24 ... /snap49870msk.xml, Default?: No, Direction: Input
# LoadMask-[Information]   Name: RefWorkspace, Value: , Default?: Yes, Direction: Input
# LoadMask-[Information]   Name: OutputWorkspace, Value: pixMsk, Default?: No, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadMask-[Information] Load File /SNS/SNAP/IPTS-24179/shared/snap49870msk.xml
# LoadMask-[Information] Successfully Load XML File
# LoadMask-[Information] Node Size = 0
# LoadMask-[Information] To Mask:
# LoadMask-[Notice] LoadMask successful, Duration 2.29 seconds
# CloneWorkspace-[Notice] CloneWorkspace started
# CloneWorkspace-[Information] Algorithm: CloneWorkspace v1
# CloneWorkspace-[Information] Execution Date: 2022-08-05 18:14:25.101037000
# CloneWorkspace-[Information] Execution Duration: -1 seconds
# CloneWorkspace-[Information] UUID: a8bc0403-db29-4f90-84a5-6ca99de36101
# CloneWorkspace-[Information] Parameters:
# CloneWorkspace-[Information]   Name: InputWorkspace, Value: TOF_48741, Default?: No, Direction: Input
# CloneWorkspace-[Information]   Name: OutputWorkspace, Value: TOF_48741_pixMsk, Default?: No, Direction: Output
# CloneWorkspace-[Notice] CloneWorkspace successful, Duration 1.32 seconds
# MaskDetectors-[Notice] MaskDetectors started
# MaskDetectors-[Information] Algorithm: MaskDetectors v1
# MaskDetectors-[Information] Execution Date: 2022-08-05 18:14:26.426289000
# MaskDetectors-[Information] Execution Duration: -1 seconds
# MaskDetectors-[Information] UUID: 8073e645-ff73-4520-bb14-e3b83a97a8da
# MaskDetectors-[Information] Parameters:
# MaskDetectors-[Information]   Name: Workspace, Value: TOF_48741_pixMsk, Default?: No, Direction: InOut
# MaskDetectors-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: DetectorList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: WorkspaceIndexList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: MaskedWorkspace, Value: pixMsk, Default?: No, Direction: Input
# MaskDetectors-[Information]   Name: ForceInstrumentMasking, Value: 0, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: StartWorkspaceIndex, Value: 0, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: EndWorkspaceIndex, Value: 2147483647, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: ComponentList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Notice] Masking using detectors IDs
# MaskDetectors-[Notice] MaskDetectors successful, Duration 0.98 seconds
# LoadMask-[Notice] LoadMask started
# LoadMask-[Information] Algorithm: LoadMask v1
# LoadMask-[Information] Execution Date: 2022-08-05 18:14:27.410967000
# LoadMask-[Information] Execution Duration: -1 seconds
# LoadMask-[Information] UUID: fbad0af1-485b-4453-bc8a-8cc246f56cd3
# LoadMask-[Information] Parameters:
# LoadMask-[Information]   Name: Instrument, Value: SNAP, Default?: No, Direction: Input
# LoadMask-[Information]   Name: InputFile, Value: /SNS/SNAP/IPTS-24 ... /snap49870msk.xml, Default?: No, Direction: Input
# LoadMask-[Information]   Name: RefWorkspace, Value: , Default?: Yes, Direction: Input
# LoadMask-[Information]   Name: OutputWorkspace, Value: pixMsk, Default?: No, Direction: Output
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadParameterFile-[Information] Parsing from XML file: /SNS/users/66j/miniconda3/envs/scippneutron/instrument/SNAP_Parameters.xml
# ExperimentInfo-[Information] run_start/start_time not stored in workspace. Default to current date.
# LoadMask-[Information] Load File /SNS/SNAP/IPTS-24179/shared/snap49870msk.xml
# LoadMask-[Information] Successfully Load XML File
# LoadMask-[Information] Node Size = 0
# LoadMask-[Information] To Mask:
# LoadMask-[Notice] LoadMask successful, Duration 2.36 seconds
# CloneWorkspace-[Notice] CloneWorkspace started
# CloneWorkspace-[Information] Algorithm: CloneWorkspace v1
# CloneWorkspace-[Information] Execution Date: 2022-08-05 18:14:29.784076000
# CloneWorkspace-[Information] Execution Duration: -1 seconds
# CloneWorkspace-[Information] UUID: f45e2f48-7be9-40d3-8a8d-83084b269af5
# CloneWorkspace-[Information] Parameters:
# CloneWorkspace-[Information]   Name: InputWorkspace, Value: TOF_rawVmB, Default?: No, Direction: Input
# CloneWorkspace-[Information]   Name: OutputWorkspace, Value: TOF_rawVmB_pixMsk, Default?: No, Direction: Output
# CloneWorkspace-[Notice] CloneWorkspace successful, Duration 1.05 seconds
# MaskDetectors-[Notice] MaskDetectors started
# MaskDetectors-[Information] Algorithm: MaskDetectors v1
# MaskDetectors-[Information] Execution Date: 2022-08-05 18:14:31.417726000
# MaskDetectors-[Information] Execution Duration: -1 seconds
# MaskDetectors-[Information] UUID: 2ad25474-8dba-4994-b5fb-7b9fc8e0d236
# MaskDetectors-[Information] Parameters:
# MaskDetectors-[Information]   Name: Workspace, Value: TOF_rawVmB_pixMsk, Default?: No, Direction: InOut
# MaskDetectors-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: DetectorList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: WorkspaceIndexList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: MaskedWorkspace, Value: pixMsk, Default?: No, Direction: Input
# MaskDetectors-[Information]   Name: ForceInstrumentMasking, Value: 0, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: StartWorkspaceIndex, Value: 0, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: EndWorkspaceIndex, Value: 2147483647, Default?: Yes, Direction: Input
# MaskDetectors-[Information]   Name: ComponentList, Value: , Default?: Yes, Direction: Input
# MaskDetectors-[Notice] Masking using detectors IDs
# MaskDetectors-[Notice] MaskDetectors successful, Duration 0.91 seconds
# ConvertUnits-[Notice] ConvertUnits started
# ConvertUnits-[Information] Algorithm: ConvertUnits v1
# ConvertUnits-[Information] Execution Date: 2022-08-05 18:14:32.325237000
# ConvertUnits-[Information] Execution Duration: -1 seconds
# ConvertUnits-[Information] UUID: 0d93481b-7107-453f-af62-0b666b69b978
# ConvertUnits-[Information] Parameters:
# ConvertUnits-[Information]   Name: InputWorkspace, Value: TOF_48741_pixMsk, Default?: No, Direction: Input
# ConvertUnits-[Information]   Name: OutputWorkspace, Value: DSpac_48741_pixMsk, Default?: No, Direction: Output
# ConvertUnits-[Information]   Name: Target, Value: dSpacing, Default?: No, Direction: Input
# ConvertUnits-[Information]   Name: EMode, Value: Elastic, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: EFixed, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: AlignBins, Value: 0, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: ConvertFromPointData, Value: 1, Default?: Yes, Direction: Input
# ConvertUnits-[Notice] ConvertUnits successful, Duration 1.55 seconds
# ConvertUnits-[Notice] ConvertUnits started
# ConvertUnits-[Information] Algorithm: ConvertUnits v1
# ConvertUnits-[Information] Execution Date: 2022-08-05 18:14:33.881318000
# ConvertUnits-[Information] Execution Duration: -1 seconds
# ConvertUnits-[Information] UUID: e467408b-1120-4f3a-8ddf-e39f069cf1d2
# ConvertUnits-[Information] Parameters:
# ConvertUnits-[Information]   Name: InputWorkspace, Value: TOF_rawVmB_pixMsk, Default?: No, Direction: Input
# ConvertUnits-[Information]   Name: OutputWorkspace, Value: DSpac_rawVmB_pixMsk, Default?: No, Direction: Output
# ConvertUnits-[Information]   Name: Target, Value: dSpacing, Default?: No, Direction: Input
# ConvertUnits-[Information]   Name: EMode, Value: Elastic, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: EFixed, Value: 8.9884656743115785e+307, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: AlignBins, Value: 0, Default?: Yes, Direction: Input
# ConvertUnits-[Information]   Name: ConvertFromPointData, Value: 1, Default?: Yes, Direction: Input
# ConvertUnits-[Notice] ConvertUnits successful, Duration 1.54 seconds
# DiffractionFocussing-[Notice] DiffractionFocussing started
# DiffractionFocussing-[Information] Algorithm: DiffractionFocussing v2
# DiffractionFocussing-[Information] Execution Date: 2022-08-05 18:14:35.427757000
# DiffractionFocussing-[Information] Execution Duration: -1 seconds
# DiffractionFocussing-[Information] UUID: 5df262c7-3104-4d01-9e42-c29aa818956d
# DiffractionFocussing-[Information] Parameters:
# DiffractionFocussing-[Information]   Name: InputWorkspace, Value: DSpac_48741_pixMsk, Default?: No, Direction: Input
# DiffractionFocussing-[Information]   Name: OutputWorkspace, Value: DSpac_48741_pixMsk_Column, Default?: No, Direction: Output
# DiffractionFocussing-[Information]   Name: GroupingFileName, Value: , Default?: Yes, Direction: Input
# DiffractionFocussing-[Information]   Name: GroupingWorkspace, Value: SNAPColumnGp, Default?: No, Direction: Input
# DiffractionFocussing-[Information]   Name: PreserveEvents, Value: 1, Default?: Yes, Direction: Input
# DiffractionFocussing-[Notice] DiffractionFocussing successful, Duration 2.38 seconds
# DiffractionFocussing-[Notice] DiffractionFocussing started
# DiffractionFocussing-[Information] Algorithm: DiffractionFocussing v2
# DiffractionFocussing-[Information] Execution Date: 2022-08-05 18:14:37.811204000
# DiffractionFocussing-[Information] Execution Duration: -1 seconds
# DiffractionFocussing-[Information] UUID: a42e2e86-5bbb-4acc-b479-275ec0163ed3
# DiffractionFocussing-[Information] Parameters:
# DiffractionFocussing-[Information]   Name: InputWorkspace, Value: DSpac_rawVmB_pixMsk, Default?: No, Direction: Input
# DiffractionFocussing-[Information]   Name: OutputWorkspace, Value: DSpac_rawVmB_pixMsk_Column, Default?: No, Direction: Output
# DiffractionFocussing-[Information]   Name: GroupingFileName, Value: , Default?: Yes, Direction: Input
# DiffractionFocussing-[Information]   Name: GroupingWorkspace, Value: SNAPColumnGp, Default?: No, Direction: Input
# DiffractionFocussing-[Information]   Name: PreserveEvents, Value: 1, Default?: Yes, Direction: Input
# DiffractionFocussing-[Notice] DiffractionFocussing successful, Duration 1.30 seconds
# StripPeaks-[Notice] StripPeaks started
# StripPeaks-[Information] Algorithm: StripPeaks v1
# StripPeaks-[Information] Execution Date: 2022-08-05 18:14:39.115423000
# StripPeaks-[Information] Execution Duration: -1 seconds
# StripPeaks-[Information] UUID: 78ea15a1-185d-4bcb-b51d-a3ed3d189347
# StripPeaks-[Information] Parameters:
# StripPeaks-[Information]   Name: InputWorkspace, Value: DSpac_rawVmB_pixMsk_Column, Default?: No, Direction: Input
# StripPeaks-[Information]   Name: OutputWorkspace, Value: DSpac_rawVmB_pixMsk_Column_strp, Default?: No, Direction: Output
# StripPeaks-[Information]   Name: FWHM, Value: 2, Default?: No, Direction: Input
# StripPeaks-[Information]   Name: Tolerance, Value: 4, Default?: Yes, Direction: Input
# StripPeaks-[Information]   Name: PeakPositions, Value: 1.22,2.04,2.11,2.19, Default?: No, Direction: Input
# StripPeaks-[Information]   Name: PeakPositionTolerance, Value: 0.01, Default?: Yes, Direction: Input
# StripPeaks-[Information]   Name: BackgroundType, Value: Quadratic, Default?: No, Direction: Input
# StripPeaks-[Information]   Name: HighBackground, Value: 1, Default?: Yes, Direction: Input
# StripPeaks-[Information]   Name: WorkspaceIndex, Value: 2147483647, Default?: Yes, Direction: Input
# StripPeaks-[Information]   Name: MaximumChisq, Value: 100, Default?: Yes, Direction: Input
# FindPeaks-[Information] Background function (Quadratic) has been created.
# FindPeaks-[Information] actual x-range = [0.329662 -> 2.23974]
# FindPeaks-[Information] practical x-range = [0.329662 -> 2.23628]
# FindPeaks-[Information] Spectrum 0: Fit peak @ d = 1.22
# FindPeaks-[Information] Fit peak with guessed FWHM:  starting center = 1.22, FWHM = 2. Estimated peak fit window from given FWHM: 1.20159, 1.2393
# FindPeaks-[Information] Fit single peak in X-range 1.20159, 1.2393, centre at 1.2203 (index = 847).
# FindPeaks-[Information] fitresult=1
# FindPeaks-[Information] Failed to get background estimation
#
# FindPeaks-[Information] FindPeakBackground Result: Given window (1.20159, 1.2393);  Determine peak range: (0, 0).
# FindPeaks-[Information] Estimated peak parameters: Centre = 1.23548, Height = 0.0404025, FWHM = 0.00190906 = 0.000953792 + 0.000955267.
# FindPeaks-[Information] [Call FitPeak] Fit 1 peak at X = 1.23548 of spectrum 0
# FindPeaks-[Information] highBkgdFit
# FindPeaks-[Information] Add user defined FWHM = 0.00190906
# FWHM to guess. Range = 2, 10; Step = 2
# Setup: i_width = 2, i_left = 854, i_right = 856, FWHM = 0.00381812, i_centre = 855.
# Setup: i_width = 4, i_left = 853, i_right = 857, FWHM = 0.00763625, i_centre = 855.
# Setup: i_width = 6, i_left = 852, i_right = 858, FWHM = 0.0114544, i_centre = 855.
# Setup: i_width = 8, i_left = 851, i_right = 859, FWHM = 0.0152726, i_centre = 855.
# Setup: i_width = 10, i_left = 850, i_right = 860, FWHM = 0.0190908, i_centre = 855.
# F1158: Well-setup and good to go!
# FitMultiDomain: Funcion MultiDomainFunction: Range: (1.20159, 1.22976) and (1.23739, 1.2393); composite=MultiDomainFunction,NumDeriv=false;name=Quadratic,A0=-1.58551,A1=1.90544,A2=0,$domains=0,1
# [DB] Multi-domain fit status: success.
# FitMultidomain: Successfully-Fitted Function name=Quadratic,A0=-23.293,A1=38.685,A2=-15.5771, Chi^2 = 0.39579
# Estimate-Peak-Height: Current peak height = 0.0404025. Estimate-Peak-Height: Maximum Y value between 1.20159 and 1.2393 is 0.0844904 at X = 1.23548.
# Round 0 of 6. Using proposed FWHM = 0.00190906
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.000810703  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.000810703","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 1.79769e+308, Fit success = 1. Store result and new Best RWP = 0.000133963.
# Round 1 of 6. Using proposed FWHM = 0.00381812
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00162141  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00162141","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 0.000133963, Fit success = 1. Round 2 of 6. Using proposed FWHM = 0.00763625
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00324282  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00324282","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 0.000133963, Fit success = 1. Store result and new Best RWP = 0.000133963.
# Round 3 of 6. Using proposed FWHM = 0.0114544
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00486423  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00486423","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 0.000133963, Fit success = 1. Round 4 of 6. Using proposed FWHM = 0.0152726
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00648566  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00648566","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 0.000133963, Fit success = 1. Round 5 of 6. Using proposed FWHM = 0.0190908
# Function (to fit): name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00810711  From 1.20159  to 1.2393.
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0844904,PeakCentre=1.23548,Sigma=0.00810711","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604: Fit-status = success, chi^2 = 0.000133963.
# Fit peak function cost = 0.000133963
# Process fit result: Rwp = 0.000133963, best Rwp = 0.000133963, Fit success = 1. Background: Pre-fit Goodness = 1.17072
# Peak+Background: Pre-fit Goodness = 0.648089
# FitSingleDomain: {"CalcErrors":true,"EndX":1.239302406764845,"Function":"name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604;name=Quadratic,A0=-23.293,A1=38.685,A2=-15.5771","InputWorkspace":"DSpac_rawVmB_pixMsk_Column","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":1.2015887988777028}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=1.20385,PeakCentre=1.24721,Sigma=0.0157456;name=Quadratic,A0=-1002.58,A1=1670.81,A2=-695.622: Fit-status = Failed to converge after 50 iterations., chi^2 = 8.98847e+307.
# Error reason of fit peak+background composite: Peak centre (at 1.24721 ) is out of specified range )1.22976, 1.23739).
# Fit peak/background composite function FAILS to render a better solution. Input cost function value = 0.648089, output cost function value = 1.79769e+308
# MultStep-Fit: Best Fitted Peak: name=Gaussian,Height=0.0565794,PeakCentre=1.23306,Sigma=0.00398604. Final Least squares = 0.648089
# Number of calls on Fit = 8
#
# FindPeaks-[Information] Failed to fit peak at 1.23306
# FindPeaks-[Information] Spectrum 0: Fit peak @ d = 2.04
# FindPeaks-[Information] Fit peak with guessed FWHM:  starting center = 2.04, FWHM = 2. Estimated peak fit window from given FWHM: 2.01012, 2.07321
# FindPeaks-[Information] Fit single peak in X-range 2.01012, 2.07321, centre at 2.04142 (index = 1180).
# FindPeaks-[Information] fitresult=2
# FindPeaks-[Information] Failed to get background estimation
#
# FindPeaks-[Information] FindPeakBackground Result: Given window (2.01012, 2.07321);  Determine peak range: (0, 0).
# FindPeaks-[Information] Estimated peak parameters: Centre = 2.03513, Height = 0.052325, FWHM = 0.00314467 = 0.00157112 + 0.00157355.
# FindPeaks-[Information] [Call FitPeak] Fit 1 peak at X = 2.03513 of spectrum 0
# FindPeaks-[Information] highBkgdFit
# FindPeaks-[Information] Add user defined FWHM = 0.00314467
# FWHM to guess. Range = 2, 10; Step = 2
# Setup: i_width = 2, i_left = 1177, i_right = 1179, FWHM = 0.00628935, i_centre = 1178.
# Setup: i_width = 4, i_left = 1176, i_right = 1180, FWHM = 0.0125787, i_centre = 1178.
# Setup: i_width = 6, i_left = 1175, i_right = 1181, FWHM = 0.0188681, i_centre = 1178.
# Setup: i_width = 8, i_left = 1174, i_right = 1182, FWHM = 0.0251575, i_centre = 1178.
# Setup: i_width = 10, i_left = 1173, i_right = 1183, FWHM = 0.031447, i_centre = 1178.
# F1158: Well-setup and good to go!
# FitMultiDomain: Funcion MultiDomainFunction: Range: (2.01012, 2.0257) and (2.04457, 2.07321); composite=MultiDomainFunction,NumDeriv=false;name=Quadratic,A0=2.20012,A1=-0.751768,A2=-15.5771,$domains=0,1
# [DB] Multi-domain fit status: success.
# FitMultidomain: Successfully-Fitted Function name=Quadratic,A0=116.477,A1=-112.65,A2=27.3886, Chi^2 = 0.24941
# ...
# FitSingleDomain: {"CalcErrors":true,"EndX":2.1562406767397739,"Function":"name=Gaussian,Height=0.790088,PeakCentre=2.11342,Sigma=0.0160043","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.0622260429919863}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.764792,PeakCentre=2.11184,Sigma=0.0124178: Fit-status = success, chi^2 = 0.000472192.
# Fit peak function cost = 0.000472192
# Process fit result: Rwp = 0.000472192, best Rwp = 0.000472192, Fit success = 1. Round 5 of 6. Using proposed FWHM = 0.0471093
# Function (to fit): name=Gaussian,Height=0.790088,PeakCentre=2.11342,Sigma=0.0200055  From 2.06223  to 2.15624.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.1562406767397739,"Function":"name=Gaussian,Height=0.790088,PeakCentre=2.11342,Sigma=0.0200055","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.0622260429919863}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.764792,PeakCentre=2.11184,Sigma=0.0124178: Fit-status = success, chi^2 = 0.000472192.
# Fit peak function cost = 0.000472192
# Process fit result: Rwp = 0.000472192, best Rwp = 0.000472192, Fit success = 1. Background: Pre-fit Goodness = 54.6791
# Peak+Background: Pre-fit Goodness = 1.62168
# FitSingleDomain: {"CalcErrors":true,"EndX":2.1562406767397739,"Function":"name=Gaussian,Height=0.764792,PeakCentre=2.11184,Sigma=0.0124178;name=Quadratic,A0=-29.1958,A1=32.3314,A2=-6.56054","InputWorkspace":"DSpac_rawVmB_pixMsk_All","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.0622260429919863}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.797965,PeakCentre=2.11425,Sigma=0.0128287;name=Quadratic,A0=66.3791,A1=-58.0778,A2=14.8097: Fit-status = success, chi^2 = 0.345706.
# Process fit result: Rwp = 0.345706, best Rwp = 1.62168, Fit success = 1. Store result and new Best RWP = 0.345706.
# MultStep-Fit: Best Fitted Peak: name=Gaussian,Height=0.797965,PeakCentre=2.11425,Sigma=0.0128287. Final Least squares = 0.345706
# Number of calls on Fit = 8
#
# FindPeaks-[Information] Spectrum 0: Fit peak @ d = 2.19
# FindPeaks-[Information] Fit peak with guessed FWHM:  starting center = 2.19, FWHM = 2. Estimated peak fit window from given FWHM: 2.14187, 2.23952
# FindPeaks-[Information] Fit single peak in X-range 2.14187, 2.23952, centre at 2.19015 (index = 855).
# FindPeaks-[Information] fitresult=2
# FindPeaks-[Information] Failed to get background estimation
#
# FindPeaks-[Information] FindPeakBackground Result: Given window (2.14187, 2.23952);  Determine peak range: (0, 0).
# FindPeaks-[Information] Estimated peak parameters: Centre = 2.19993, Height = 0.617024, FWHM = 0.0293896 = 0.0170948 + 0.0122948.
# FindPeaks-[Information] [Call FitPeak] Fit 1 peak at X = 2.19993 of spectrum 0
# FindPeaks-[Information] highBkgdFit
# FindPeaks-[Information] Add user defined FWHM = 0.0293896
# FWHM to guess. Range = 2, 10; Step = 2
# Setup: i_width = 2, i_left = 856, i_right = 858, FWHM = 0.00980737, i_centre = 857.
# Setup: i_width = 4, i_left = 855, i_right = 859, FWHM = 0.0196148, i_centre = 857.
# Setup: i_width = 6, i_left = 854, i_right = 860, FWHM = 0.0294223, i_centre = 857.
# Setup: i_width = 8, i_left = 853, i_right = 861, FWHM = 0.03923, i_centre = 857.
# Setup: i_width = 10, i_left = 852, i_right = 862, FWHM = 0.0490378, i_centre = 857.
# F1158: Well-setup and good to go!
# FitMultiDomain: Funcion MultiDomainFunction: Range: (2.14187, 2.15624) and (2.22459, 2.23952); composite=MultiDomainFunction,NumDeriv=false;name=Quadratic,A0=9.08547,A1=0.432141,A2=14.8097,$domains=0,1
# [DB] Multi-domain fit status: success.
# FitMultidomain: Successfully-Fitted Function name=Quadratic,A0=20.6687,A1=-10.1791,A2=2.4273, Chi^2 = 0.208997
# Estimate-Peak-Height: Current peak height = 0.617024. Estimate-Peak-Height: Maximum Y value between 2.14187 and 2.23952 is 0.630339 at X = 2.19993.
# Round 0 of 6. Using proposed FWHM = 0.0293896
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0124806  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0124806","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 1.79769e+308, Fit success = 1. Store result and new Best RWP = 0.000539016.
# Round 1 of 6. Using proposed FWHM = 0.00980737
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.00416481  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.00416481","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 0.000539016, Fit success = 1. Store result and new Best RWP = 0.000539016.
# Round 2 of 6. Using proposed FWHM = 0.0196148
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.00832964  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.00832964","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 0.000539016, Fit success = 1. Round 3 of 6. Using proposed FWHM = 0.0294223
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0124945  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0124945","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 0.000539016, Fit success = 1. Round 4 of 6. Using proposed FWHM = 0.03923
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0166594  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0166594","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 0.000539016, Fit success = 1. Round 5 of 6. Using proposed FWHM = 0.0490378
# Function (to fit): name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0208245  From 2.14187  to 2.23952.
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.630339,PeakCentre=2.19993,Sigma=0.0208245","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128: Fit-status = success, chi^2 = 0.000539016.
# Fit peak function cost = 0.000539016
# Process fit result: Rwp = 0.000539016, best Rwp = 0.000539016, Fit success = 1. Background: Pre-fit Goodness = 28.7732
# Peak+Background: Pre-fit Goodness = 0.955046
# FitSingleDomain: {"CalcErrors":true,"EndX":2.2395154194728697,"Function":"name=Gaussian,Height=0.57476,PeakCentre=2.19616,Sigma=0.0128;name=Quadratic,A0=20.6687,A1=-10.1791,A2=2.4273","InputWorkspace":"DSpac_rawVmB_pixMsk_All","MaxIterations":50,"Minimizer":"Levenberg-MarquardtMD","StartX":2.1418699088369184}.
# [F1201] FitSingleDomain Fitted-Function name=Gaussian,Height=0.589196,PeakCentre=2.19879,Sigma=0.0131932;name=Quadratic,A0=40.1208,A1=-27.6381,A2=6.34037: Fit-status = success, chi^2 = 0.287249.
# Process fit result: Rwp = 0.287249, best Rwp = 0.955046, Fit success = 1. Store result and new Best RWP = 0.287249.
# MultStep-Fit: Best Fitted Peak: name=Gaussian,Height=0.589196,PeakCentre=2.19879,Sigma=0.0131932. Final Least squares = 0.287249
# Number of calls on Fit = 8
#
# FindPeaks-[Information] Total 4 peaks found and successfully fitted.
# StripPeaks-[Information] Call FindPeaks() to find 4 peaks with parameters:
# 	 FWHM            = 2;
# 	 Tolerance       = 4;
# 	 HighBackground  = 1;
# 	 BackgroundType  = Quadratic;
# 	 Peak positions  = 1.22, 2.04, 2.11, 2.19)
# Returned number of fitted peak = 4.
# StripPeaks-[Information] Subtracting peak 0 from spectrum 0 at x = 1.21994 h = 0.358118 s = 0.00667516 chi2 = 0.261457
# StripPeaks-[Information]      background = 137.522 + -222.637 x + 93.9867 x^2
# StripPeaks-[Information] Subtracting peak 1 from spectrum 0 at x = 2.0441 h = 0.508345 s = 0.0135777 chi2 = 0.32426
# StripPeaks-[Information]      background = 399.951 + -387.896 x + 96.2732 x^2
# StripPeaks-[Information] Subtracting peak 2 from spectrum 0 at x = 2.11425 h = 0.797965 s = 0.0128287 chi2 = 0.345706
# StripPeaks-[Information]      background = 66.3791 + -58.0778 x + 14.8097 x^2
# StripPeaks-[Information] Subtracting peak 3 from spectrum 0 at x = 2.19879 h = 0.589196 s = 0.0131932 chi2 = 0.287249
# StripPeaks-[Information]      background = 40.1208 + -27.6381 x + 6.34037 x^2
# StripPeaks-[Notice] StripPeaks successful, Duration 0.91 seconds
# SmoothData-[Notice] SmoothData started
# SmoothData-[Information] Algorithm: SmoothData v1
# SmoothData-[Information] Execution Date: 2022-08-05 18:16:30.582676000
# SmoothData-[Information] Execution Duration: -1 seconds
# SmoothData-[Information] UUID: e0bbfa29-920b-432d-a0d1-60a6bdc23e5b
# SmoothData-[Information] Parameters:
# SmoothData-[Information]   Name: InputWorkspace, Value: DSpac_rawVmB_pixMsk_All_strp, Default?: No, Direction: Input
# SmoothData-[Information]   Name: OutputWorkspace, Value: DSpac_VCorr_pixMsk_All, Default?: No, Direction: Output
# SmoothData-[Information]   Name: NPoints, Value: 9, Default?: No, Direction: Input
# SmoothData-[Information]   Name: GroupingWorkspace, Value: , Default?: Yes, Direction: Input
# SmoothData-[Notice] SmoothData successful, Duration 0.49 seconds
# Divide-[Notice] Divide started
# Divide-[Information] Algorithm: Divide v1
# Divide-[Information] Execution Date: 2022-08-05 18:16:31.075436000
# Divide-[Information] Execution Duration: -1 seconds
# Divide-[Information] UUID: 16d66543-0e65-45c1-9b96-b186048c8f2f
# Divide-[Information] Parameters:
# Divide-[Information]   Name: LHSWorkspace, Value: DSpac_49854_pixMsk_All, Default?: No, Direction: Input
# Divide-[Information]   Name: RHSWorkspace, Value: DSpac_VCorr_pixMsk_All, Default?: No, Direction: Input
# Divide-[Information]   Name: OutputWorkspace, Value: DSpac_49854_pixMsk_All_V, Default?: No, Direction: Output
# Divide-[Information]   Name: AllowDifferentNumberSpectra, Value: 0, Default?: Yes, Direction: Input
# Divide-[Information]   Name: ClearRHSWorkspace, Value: 0, Default?: Yes, Direction: Input
# Divide-[Information]   Name: WarnOnZeroDivide, Value: 1, Default?: Yes, Direction: Input
# Divide-[Notice] Divide successful, Duration 2.39 seconds
# Rebin-[Notice] Rebin started
# Rebin-[Information] Algorithm: Rebin v1
# Rebin-[Information] Execution Date: 2022-08-05 18:16:33.468984000
# Rebin-[Information] Execution Duration: -1 seconds
# Rebin-[Information] UUID: 0a85e5a3-68c9-47d9-b37c-9afd21c970b2
# Rebin-[Information] Parameters:
# Rebin-[Information]   Name: InputWorkspace, Value: DSpac_49854_pixMsk_All_V, Default?: No, Direction: Input
# Rebin-[Information]   Name: OutputWorkspace, Value: DSpac_49854_pixMsk_All_VR, Default?: No, Direction: Output
# Rebin-[Information]   Name: Params, Value: 0.5,-0.001,4.5, Default?: No, Direction: Input
# Rebin-[Information]   Name: PreserveEvents, Value: 0, Default?: No, Direction: Input
# Rebin-[Information]   Name: FullBinsOnly, Value: 0, Default?: Yes, Direction: Input
# Rebin-[Information]   Name: IgnoreBinErrors, Value: 0, Default?: Yes, Direction: Input
# Rebin-[Information] Creating a Workspace2D from the EventWorkspace DSpac_49854_pixMsk_All_V.
# Rebin-[Notice] Rebin successful, Duration 1.51 seconds
# CropWorkspaceRagged-[Notice] CropWorkspaceRagged started
# CropWorkspaceRagged-[Information] Algorithm: CropWorkspaceRagged v1
# CropWorkspaceRagged-[Information] Execution Date: 2022-08-05 18:16:34.984729000
# CropWorkspaceRagged-[Information] Execution Duration: -1 seconds
# CropWorkspaceRagged-[Information] UUID: 41da2cf6-d3d7-42c2-803e-316541322a4a
# CropWorkspaceRagged-[Information] Parameters:
# CropWorkspaceRagged-[Information]   Name: InputWorkspace, Value: DSpac_49854_pixMsk_All_VR, Default?: No, Direction: Input
# CropWorkspaceRagged-[Information]   Name: OutputWorkspace, Value: DSpac_49854_pixMsk_All_VRT, Default?: No, Direction: Output
# CropWorkspaceRagged-[Information]   Name: XMin, Value: 0.65, Default?: No, Direction: Input
# CropWorkspaceRagged-[Information]   Name: XMax, Value: 2.8, Default?: No, Direction: Input
# CropWorkspaceRagged-[Notice] CropWorkspaceRagged successful, Duration 1.42 seconds
# DeleteWorkspaces-[Notice] DeleteWorkspaces started
# DeleteWorkspaces-[Information] Algorithm: DeleteWorkspaces v1
# DeleteWorkspaces-[Information] Execution Date: 2022-08-05 18:16:36.478400000
# DeleteWorkspaces-[Information] Execution Duration: -1 seconds
# DeleteWorkspaces-[Information] UUID: 8d0d4019-b140-41a5-a78d-b95c879f1bf3
# DeleteWorkspaces-[Information] Parameters:
# DeleteWorkspaces-[Information]   Name: WorkspaceList, Value: DSpac_rawVmB_pixM ... 854_pixMsk_All_VR, Default?: No, Direction: Input
# DeleteWorkspaces-[Notice] DeleteWorkspaces successful, Duration 0.00 seconds
# GroupWorkspaces-[Notice] GroupWorkspaces started
# GroupWorkspaces-[Information] Algorithm: GroupWorkspaces v1
# GroupWorkspaces-[Information] Execution Date: 2022-08-05 18:16:37.663936000
# GroupWorkspaces-[Information] Execution Duration: -1 seconds
# GroupWorkspaces-[Information] UUID: 49b6f51d-90ca-4675-bb40-6224e2635bcf
# GroupWorkspaces-[Information] Parameters:
# GroupWorkspaces-[Information]   Name: InputWorkspaces, Value: TOF_49854_monitor ... 54_pixMsk_All_VRT, Default?: No, Direction: Input
# GroupWorkspaces-[Information]   Name: GlobExpression, Value: , Default?: Yes, Direction: Input
# GroupWorkspaces-[Information]   Name: OutputWorkspace, Value: SNAP49854_Red, Default?: No, Direction: Output
# GroupWorkspaces-[Notice] GroupWorkspaces successful, Duration 0.00 seconds
# DeleteWorkspaces-[Notice] DeleteWorkspaces started
# DeleteWorkspaces-[Information] Algorithm: DeleteWorkspaces v1
# DeleteWorkspaces-[Information] Execution Date: 2022-08-05 18:16:37.665494000
# DeleteWorkspaces-[Information] Execution Duration: -1 seconds
# DeleteWorkspaces-[Information] UUID: f8d04aa5-65d8-4a76-8861-611e1966f719
# DeleteWorkspaces-[Information] Parameters:
# DeleteWorkspaces-[Information]   Name: WorkspaceList, Value: TOF_49854_pixMsk, ... Spac_49854_pixMsk, Default?: No, Direction: Input
# DeleteWorkspaces-[Notice] DeleteWorkspaces successful, Duration 0.00 seconds
# DeleteWorkspaces-[Notice] DeleteWorkspaces started
# DeleteWorkspaces-[Information] Algorithm: DeleteWorkspaces v1
# DeleteWorkspaces-[Information] Execution Date: 2022-08-05 18:16:40.880618000
# DeleteWorkspaces-[Information] Execution Duration: -1 seconds
# DeleteWorkspaces-[Information] UUID: f0a5efc4-38ac-4a8e-9b70-c4ad04209ab6
# DeleteWorkspaces-[Information] Parameters:
# DeleteWorkspaces-[Information]   Name: WorkspaceList, Value: TOF_rawVmB_pixMsk, Default?: No, Direction: Input
# DeleteWorkspaces-[Notice] DeleteWorkspaces successful, Duration 0.00 seconds
# SNAPRed complete
