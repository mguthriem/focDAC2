# %% [markdown]
# # prototype panels interface for SNAP reduce

# %%
from mantid.simpleapi import *
from mantid import config
config.setLogLevel(0, quiet=True)
import time
import numpy as np

import FocDACUtilities as DAC
import SNAP_InstPrm as iPrm 
import importlib
importlib.reload(DAC)

importlib.reload(iPrm)
import panel as pn
#from panel.template import DarkTheme

pn.extension(template='material')
pn.widgets.Select.sizing_mode = 'stretch_both'

import pandas as pd
# Out:
# ConfigService-[Information] Unable to locate directory at: /etc/mantid/instrument
# ConfigService-[Information] This is Mantid version 6.2.0 revision gbf806d7983f
# ConfigService-[Information] running on analysis-node16.sns.gov starting 2022-09-08T15:46Z
# ConfigService-[Information] Properties file(s) loaded: /SNS/users/66j/miniconda3/envs/scippneutron/bin/Mantid.properties, /etc/mantid.local.properties, /SNS/users/66j/.mantid/Mantid.user.properties
# ConfigService-[Information] Unable to locate directory at: /etc/mantid/instrument
# FrameworkManager-[Notice] Welcome to Mantid 6.2.0
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid6.2
# FrameworkManager-[Information] Version check disabled.
# GitHubApiHelper-[Information] Making unauthenticated calls to GitHub
# GitHubApiHelper-[Information] Making unauthenticated calls to GitHub
# DownloadInstrument-[Notice] All instrument definitions up to date
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
importlib.reload(DAC)
config.setLogLevel(6, quiet=False)
# Out:
# ConfigService-[Information] logging set to PRIO_INFORMATION priority

# %%
#bootstrap = pn.template.BootstrapTemplate(title = 'SNAPReduce 2.0 ...The Second Coming!')
#set up some widgets
#Tab1:
#column1:
importlib.reload(DAC)
stat = pn.pane.Markdown("")
runInput = pn.widgets.TextInput(name='Run Number')
liteMode_Toggle = pn.widgets.Toggle(name='Select Lite',value=True)
red_Button = pn.widgets.Button(name='Reduce',button_type='primary',disabled=True)
calibState_Toggle = pn.widgets.RadioButtonGroup(name='Calib. status relative to run ?',
                                               options=['Before','After','Manual'],value='Before')
red_Status = pn.widgets.TextInput(name='Reduction Status',value='idle')
progress = pn.indicators.Progress(name='Progress', value=20, width=200)

#column2 (ERROR NOTIFICATION)
#abutton = pn.widgets.Button(name='Something went wrong press me!',button_type='danger',visible=False)
AlertText = """
##ERROR: Something went wrong!

Reduction is only possible for calibrated instrument configurations.

<hr>

"""
Alert = pn.pane.Alert(AlertText, alert_type="danger")
Alert.visible = False
#someMarkdown.visible=False

#Tab2:

maskNameInput_wgt= pn.widgets.FileSelector(name='mask file',directory='/SNS/SNAP/shared',file_pattern='*msk.*')
maskName = pn.widgets.TextInput(name='Pixel Mask FileName',value='')


CU_Toggle = pn.widgets.Toggle(name='ConvertUnits')
GSASOut_Toggle = pn.widgets.Toggle(name='Output to GSAS')
AsciiOut_Toggle = pn.widgets.Toggle(name='Output Ascii as csv')
cleanUp_Toggle = pn.widgets.Toggle(name='Clean Up Workspaces',value=True)
rebin_FloatSlider = pn.widgets.FloatSlider(name='Down Sample Binning',start = 0.0, end = 10.0, step = 1,value=0)

#Tab3:
groupSelect_Toggle = pn.widgets.RadioButtonGroup(name='Detector Grouping',
                                                 options=['Column','Bank','All'],value='Column')
png = pn.panel('https://upload.wikimedia.org/wikipedia/commons/4/47/PNG_transparency_demonstration_1.png', width=500)

def stateStatus(target, event):

    runLst = event.new
    runs=runLst.strip().split(',')
    stateID,sDict,errorState = DAC.StateFromRunFunction(runs[0])
    # there are a great number of ways that the above function can fail.
    # I have edited it (and all sub functions) to pass errorState a dictionary
    # with sufficient information to handle exceptions
    
    if errorState['value']==0:
        stateString = (f'''

        ### State ID: {stateID}


        |Parameter    | Value                 | 
        |-------------|-----------------------|
        |det1         | {sDict["det_arc1"]:.1f}  |
        |det_arc2     | {sDict["det_arc2"]:.1f}   |
        |wav          | {sDict["wav"]:.2f}        |
        |freq         | {sDict["freq"]:.2f}    |
        |guide status:| {sDict["GuideStat"]}  |

        State calibration folder: 
        {iPrm.stateLoc}{stateID}/
        
                      ''')
        target.object = stateString
    
#        sPrm = DAC.getStatePrm(int(runs[0]),calibState_Toggle.value)

        red_Button.disabled = False
        Alert.visible = False
        sPrm_df = pd.DataFrame.from_dict(sPrm)
        prm_df = pn.pane.DataFrame(sPrm_df,width=400)
    else:
        stateString = (f'''
        
        ###An error has occurred: 
        
        * function: {errorState['function']} failed
        * ERROR: {errorState['value']} - {errorState['message']}
        * details: {errorState['parameters']} 
        
        
        ''')
        target.object = stateString
        red_Button.disabled = True
        Alert.visible = True
        #abutton.visible=True
        #someMarkdown.visible=True
        #sPrm = dict()
    return #sPrm

#runInput is a text input field

runInput.link(stat,callbacks={'value': stateStatus})
runInput.value=""

    
# initialise_Button.on_click(b)

# col1 = pn.Column(t,initialise_Button,CU_Toggle,GSASOut_Toggle,calibState_Toggle)
# col2 = pn.Column(m)
col1a = pn.Column(runInput,maskName,liteMode_Toggle,red_Button,red_Status,stat)
col1b = pn.Column(Alert)
row1 = pn.Row(col1a,col1b)
col2 = pn.Column(pn.pane.Str('Select calibration mode:'),calibState_Toggle,CU_Toggle,GSASOut_Toggle,AsciiOut_Toggle,cleanUp_Toggle)
col3 = pn.Column(groupSelect_Toggle,rebin_FloatSlider, png)

tabs = pn.Tabs()
tabs.append(('Main',row1))
tabs.append(('Advanced Settings',col2))
tabs.append(('Visualisation',col3))

#define action when reduce button is pressed

def b(event):
    red_Status.value = 'Working...sorry this is slow'
    settings = dict()
    settings['calibState']=calibState_Toggle.value
    settings['GSASOut']=GSASOut_Toggle.value
    settings['ConvertUnits']=CU_Toggle.value
    settings['cleanUp']=cleanUp_Toggle.value
    setting['liteMode']=liteMode_Toggle.value
    time_0 = time.time()
    DAC.SNAPRed(runInput.value,maskName.value,settings)
    #print('Time to load calibration {}'.format(time.time() - time_0))
    timeInMins=(time.time()-time_0)/60
    red_Status.value = f'Complete - time taken was: {timeInMins:.3f} mins'
    return 'a return string'

red_Button.on_click(b)

# print(something)

main = pn.Column('# SNAPReduce 2.0',
    pn.layout.Divider(),
    tabs,
    background='whitesmoke', width=800)
main
# Out:
# <pre>Traceback (most recent call last):
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/pyviz_comms/__init__.py&quot;, line 338, in _handle_msg
#     self._on_msg(msg)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/viewable.py&quot;, line 292, in _on_msg
#     doc.unhold()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/document.py&quot;, line 799, in unhold
#     self.callbacks.unhold()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 396, in unhold
#     self.trigger_on_change(event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 373, in trigger_on_change
#     invoke_with_curdoc(doc, event.callback_invoker)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/util/callback_manager.py&quot;, line 191, in invoke
#     callback(attr, old, new)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 392, in _comm_change
#     self._schedule_change(doc, comm)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 376, in _schedule_change
#     self._change_event(doc)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 370, in _change_event
#     self._process_events(events)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 315, in _process_events
#     self.param.update(**self_events)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 1898, in update
#     self_._batch_call_watchers()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 2059, in _batch_call_watchers
#     self_._execute_watcher(watcher, events)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 2021, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 492, in link_cb
#     callbacks[event.name](target, event)
#   File &quot;/tmp/ipykernel_99155/3447751886.py&quot;, line 79, in stateStatus
#     sPrm_df = pd.DataFrame.from_dict(sPrm)
# NameError: name &#x27;sPrm&#x27; is not defined
# </pre>
#
#
# <pre>Traceback (most recent call last):
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/pyviz_comms/__init__.py&quot;, line 338, in _handle_msg
#     self._on_msg(msg)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/viewable.py&quot;, line 291, in _on_msg
#     patch.apply_to_document(doc, comm.id if comm else None)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/protocol/messages/patch_doc.py&quot;, line 115, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/protocol/messages/patch_doc.py&quot;, line 115, in &lt;lambda&gt;
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/document.py&quot;, line 391, in apply_json_patch
#     DocumentPatchedEvent.handle_json(self, event_json, references, setter)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/events.py&quot;, line 259, in handle_json
#     handler(doc, event_json, references, setter)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/events.py&quot;, line 300, in _handle_json
#     cb(event_json[&quot;msg_data&quot;])
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 355, in trigger_json_event
#     model._trigger_event(event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/util/callback_manager.py&quot;, line 119, in _trigger_event
#     self.document.callbacks.notify_event(cast(Model, self), event, invoke)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 247, in notify_event
#     invoke_with_curdoc(doc, callback_invoker)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/document/callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/bokeh/util/callback_manager.py&quot;, line 115, in invoke
#     cast(EventCallbackWithEvent, callback)(event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 398, in _comm_event
#     self._process_bokeh_event(event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/reactive.py&quot;, line 345, in _process_bokeh_event
#     self._process_event(event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/panel/widgets/button.py&quot;, line 176, in _process_event
#     self.clicks += 1
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 367, in _f
#     instance_param.__set__(obj, val)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 369, in _f
#     return f(self, obj, val)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/__init__.py&quot;, line 625, in __set__
#     super(Dynamic,self).__set__(obj,val)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 369, in _f
#     return f(self, obj, val)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 1248, in __set__
#     obj.param._call_watcher(watcher, event)
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 2039, in _call_watcher
#     self_._execute_watcher(watcher, (event,))
#   File &quot;/SNS/users/66j/miniconda3/envs/scippneutron/lib/python3.8/site-packages/param/parameterized.py&quot;, line 2021, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File &quot;/tmp/ipykernel_99155/3447751886.py&quot;, line 130, in b
#     setting[&#x27;liteMode&#x27;]=liteMode_Toggle.value
# NameError: name &#x27;setting&#x27; is not defined
# </pre>
# Column(background='whitesmoke', width=800)
#     [0] Markdown(str)
#     [1] Divider()
#     [2] Tabs
#         [0] Row
#             [0] Column
#                 [0] TextInput(name='Run Number')
#                 [1] TextInput(name='Pixel Mask FileName')
#                 [2] Toggle(name='Select Lite', value=True)
#                 [3] Button(button_type='primary', disabled=True, name='Reduce')
#                 [4] TextInput(name='Reduction Status', value='idle')
#                 [5] Markdown(str)
#             [1] Column
#                 [0] Alert(str, alert_type='danger', css_classes=['alert', 'alert-danger'], margin=(0, 0, 25, 0), sizing_mode='stretch_width', visible=False)
#         [1] Column
#             [0] Str(str)
#             [1] RadioButtonGroup(name='Calib. status r..., options=['Before', 'After', ...], value='Before')
#             [2] Toggle(name='ConvertUnits')
#             [3] Toggle(name='Output to GSAS')
#             [4] Toggle(name='Output Ascii as csv')
#             [5] Toggle(name='Clean Up Workspaces', value=True)
#         [2] Column
#             [0] RadioButtonGroup(name='Detector Grouping', options=['Column', 'Bank', 'All'], value='Column')
#             [1] FloatSlider(end=10.0, name='Down Sample Binning', step=1)
#             [2] PNG(str, width=500)

# %%
names = mtd.getObjectNames()
for name in names:
    print(name)
# Out:
# CommonRed
# lite
# SNAPAllGp
# SNAPColumnGp
# SNAPGroupGp
# TOF_48746
# TOF_48746_binMsk
# TOF_48746_monitors
# TOF_rawVmB
# TOF_rawVmB_binMsk

# %%
import json
mskFname='/SNS/SNAP/IPTS-24179/shared/snap48746lite_binMskInfo.json'

with open(mskFname, "r") as json_file:
    mskBinsDict = json.load(json_file)
    mask_xmins = mskBinsDict['xmins']
    mask_xmaxs = mskBinsDict['xmaxs']
    mask_spectraLsts = mskBinsDict['spectraLsts']
    mask_units = mskBinsDict['units']
    nmask_slice = len(mask_xmins)

print(f'there are {nmask_slice} slices')
# Out:
# there are 42 slices

# %%
mskRunWS = 'TOF_48746_binMsk'
for kk in range(nmask_slice):
    MaskBins(InputWorkspace=mskRunWS,
                InputWorkspaceIndexType='WorkspaceIndex',
                InputWorkspaceIndexSet=mask_spectraLsts[kk],
                OutputWorkspace=mskRunWS,
                XMin=mask_xmins[kk],
                XMax=mask_xmaxs[kk])
# Out:
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.269844000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 26eaf278-8cb9-4967-89a2-dd481815c811
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 5009,5038-5042,50 ... 17365,17390-17396, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.6291294255733573, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.6799408008354835, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.275798000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 81e1766e-0eaf-4e1c-8575-96ac4794c341
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7182-7187,7212-72 ... 70,7499-7502,7532, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.5275066750491049, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.6255000416260628, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.02 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.293845000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 559ebce9-87da-400f-a464-e398d248cb5a
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7663-7666,7693-76 ... 17262-17267,17296, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.4476602282086208, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.5456535947855787, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.300601000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 1c54c24a-21c9-496d-b87e-e36e028dc934
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7247-7248,7278-72 ... 14143,14173-14174, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.3823313171573157, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.4803246837342736, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.305469000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: c0edf4df-0332-4f3f-a023-c7108f7dfa9a
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7407,7437-7440,74 ... 17363,17382-17395, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.1210156729520953, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.2190090395290527, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.310475000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: a4347e27-0d83-4726-8adf-35755b135a9d
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7661-7664,7693-76 ... 17363,17393-17394, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 3.0085047705859589, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 3.1064981371629168, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.315345000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 6a94ecda-315f-476f-9309-c8065023427c
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7728,7758-7761,77 ... 17166-17169,17199, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.8633294126941697, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.9613227792711276, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.320145000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 5fd4c392-6047-4a20-b5a7-56a6c861ba2d
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7885-7886,7916-79 ... 17138,17167-17170, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.8052592695374541, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.9032526361144115, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.326394000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 4af69743-0d1a-4502-8e24-6efecf1cbafc
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7598,7629-7632,76 ... 17327,17330-17332, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.7471891263807384, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.8451824929576959, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.332695000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: d2036d78-793a-467a-85e6-37a4f838396c
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7566,7597-7599,76 ... 17334,17361-17364, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.7471891263807384, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.8451824929576959, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.338730000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: c9b208c0-e2cf-4357-99ac-abb1fb6d33e4
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7567,7597-7601,76 ... 17240,17260-17270, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.6891189832240228, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.7871123498009807, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.344825000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: d5bcb03c-110d-40ff-8987-cc8df9dcccea
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7752-7756,7783-77 ... 17113,17142-17144, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.6310488400673071, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.7290422066442646, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.349678000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: e809617e-00e1-4e7c-a9a3-3cb04a11e654
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 7732,7762-7765,77 ... 17061-17064,17095, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.6310488400673071, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.7290422066442646, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.356627000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 46aae2fd-d28a-4d40-9b80-50b1699c71fa
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 8015,8042-8049,80 ... 16971,17000-17002, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.5330554734903492, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.6310488400673071, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.360278000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 7b75d30c-dba7-47ae-ae43-6ec8b954c226
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1951,2015,2047,22 ... 18404,18416-18420, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.4604677945444551, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.5584611611214125, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.366586000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 00f56b73-dbbc-4637-9bc7-5ada8d17bec4
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 523,554-557,583-5 ... 18394,18419-18426, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.3733625798093811, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.471355946386339, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.371843000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: a59b331b-1fbc-4409-9c09-2a48c6756517
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 2579-2581,2611-26 ... 17788,17818-17819, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.3733625798093811, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.471355946386339, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.373668000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 035f3a81-a9ca-4b0d-85c8-57e9246fd942
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 874,905-908,936-9 ... 18267,18296-18298, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.3080336687580765, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.4060270353350339, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.376181000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 36c263e5-5e99-46d8-9315-344535a34e73
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 13518-13521,13550 ... 14131,14158-14162, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.2245578379702975, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.3225512045472554, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.377851000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 400f73ef-f882-40cd-a64d-de68a5fe1ae2
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 10927-10929,10957 ... 14033,14063-14065, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.1628583108662873, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.2608516774432448, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.379526000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 6c5dd6dc-63b2-41fe-996d-06c7561c2f15
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 10828,10830-10834 ... 13939,13967-13969, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.0902706319203928, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.1882639984973506, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.380894000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 6eabd148-6660-49c4-a3c2-2702dd25a4fe
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 13390,13420-13424 ... 13776,13806-13807, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.9922772653434351, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.0902706319203928, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.02 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.399012000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: ddf83651-66da-4700-9536-58fc092674d0
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 11156-11157,11187 ... 14231,14260-14262, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.9051720506083616, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.0031654171853193, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.406962000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: b8c3cdef-d086-42b2-86b1-3b96aee769f7
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 153-154,182-188,2 ... 17120-17121,17152, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.8398431395570565, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.9378365061340139, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.409560000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 35ff69ae-982a-4ead-9216-613bf695b1c5
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1492-1493,1518-15 ... 17249,17280,17409, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.7672554606111619, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.8652488271881196, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.411716000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: ae80966d-422b-4c2f-aeb1-f813adc43be8
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1547-1561,1574-15 ... 13317,13346-13348, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.7055559335071513, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.803549300084109, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.415019000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 0013eb16-bca6-4331-886b-0351e8036256
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 3423,3454-3455,34 ... 18303,18334-18335, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.6402270224558464, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.7382203890328038, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.423029000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 400390ae-8bc7-428c-82cc-3a396b4d8905
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1357-1362,1388-13 ... 25,1548-1556,1583, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.2881767795682579, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.3861701461452154, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.424403000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 41831ffc-aa65-4835-9a59-9d46c99c96d9
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1229-1233,1259-12 ... 10837,10867-10868, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.2264772524642473, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.324470619041205, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.425879000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 6230885c-b6f6-47cf-8310-98c0d5a76a19
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 1323-1330,1351-13 ... 14583-14585,14616, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.1611483414129424, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.2591417079898999, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.431399000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 291fef6f-ecf3-4c9b-86d4-e0a32cc3dc87
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 4302,4329-4339,43 ... 89-8991,9021-9023, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.0958194303616373, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.193812796938595, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.436509000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 32fd88a2-33c6-4357-a813-562f194042e6
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 4527-4530,4553,45 ... 18079,18110-18111, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 1.0304905193103322, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.1284838858872899, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.442667000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 9bd03351-6c8f-429e-81a6-33a8759b0260
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 768-770,800-803,8 ... 17855,17886-17887, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.96516160825902686, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 1.0631549748359848, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.450509000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 7ac6b77d-8359-45a8-a150-4be6af3d97e5
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 801-805,832-838,8 ... 13251,13281-13282, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.89620331326042713, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.99419667983738469, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.461943000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 56df6f3f-3415-408f-8533-ca345ac11010
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 100-101,131-134,1 ... 15693,15723-15724, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.82724501826182728, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.92523838483878484, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.464988000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: f8fb7b73-2676-4b8c-ba3b-ec176fc2fc26
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 97-101,128-133,16 ... 18006,18035-18036, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.73651041957945917, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.83450378615641674, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.469071000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: e1894777-bb0e-4c5b-81af-0652af47790c
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 3531-3535,3561-35 ... 18386,18414-18418, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.66755212458085933, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.76554549115781689, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.472111000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 9e5a6a7a-9000-4671-8e81-2d19e1aa1004
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 5930-5931,5961-59 ... 14436,14438-14450, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.66755212458085933, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.76554549115781689, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.473950000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: acfd9780-7759-4d4b-af4b-46bbeb8af214
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 916,947-950,978-9 ... 18384,18411-18415, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.59859382958225937, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.69658719615921705, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.475534000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: 399a2096-da7c-4adf-8f07-5b43a5320cec
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 208-210,239-247,2 ... 15306,15334-15338, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.53326491853095426, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 0.63125828510791193, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.01 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.489315000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: cca0d765-7ab2-4560-8d32-aa7f97dd7f73
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 16852-16854,16883 ... 16983,17012-17015, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 2.6000000000000001, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 2.7000000000000002, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds
# MaskBins-[Notice] MaskBins started
# MaskBins-[Information] Algorithm: MaskBins v1
# MaskBins-[Information] Execution Date: 2022-09-08 13:59:42.491024000
# MaskBins-[Information] Execution Duration: -1 seconds
# MaskBins-[Information] UUID: b61c943c-36c0-4e40-aaeb-37aa670437c0
# MaskBins-[Information] Parameters:
# MaskBins-[Information]   Name: InputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexType, Value: WorkspaceIndex, Default?: No, Direction: Input
# MaskBins-[Information]   Name: InputWorkspaceIndexSet, Value: 4621-4622,4652-46 ... 16817,16846-16849, Default?: No, Direction: Input
# MaskBins-[Information]   Name: OutputWorkspace, Value: TOF_48746_binMsk, Default?: No, Direction: Output
# MaskBins-[Information]   Name: XMin, Value: 0.83879675149706012, Default?: No, Direction: Input
# MaskBins-[Information]   Name: XMax, Value: 4.2424953126661658, Default?: No, Direction: Input
# MaskBins-[Information]   Name: SpectraList, Value: , Default?: Yes, Direction: Input
# MaskBins-[Notice] MaskBins successful, Duration 0.00 seconds

# %% [markdown]
# ## Delete workspaces
#
# Use this to clear house. At the moment not sure how to keep track of memory usage in a jupyter notebook, but it certainly will build up same as workbench

# %%
names = mtd.getObjectNames()
for workspace in names :
        DeleteWorkspace(workspace)

# %% [markdown]
# ## Create a filtered list of reduced workspaces and prepare for plotting
#
# Has possiblity to filter according to string, this will control what is available for plotting below

# %%
print('List of mantid workspaces generated:')
names = mtd.getObjectNames()

filter = 'DSpac' #a single string that must exist in workspace name
                # all reduced workspaces (atm) have 'Msk' in their names
                #other ws may exist but won't be displayed here.

useRunLst = []
for workspace in names :
    if filter in workspace:
        ws = mtd[workspace]
        nHst = ws.getNumberHistograms()
        print(f'workspace: {workspace} contains {nHst} histograms')
        wsStr=workspace.split('_')
        if len(wsStr)>1: #this is a data workspace
            useRunLst.append(wsStr[1])
            mskTag=wsStr[2]
useRunLst = [*set(useRunLst)] #remove duplicates
useRunLst = sorted([int(x) for x in useRunLst])
print(f'Generated useRunLst: {useRunLst}')
print(f'masktag: {mskTag}')
# a=sorted(useRunLst)
# print(a)
# Out:
# List of mantid workspaces generated:
# workspace: DSpac_48746_noMsk_All_VRT contains 1 histograms
# workspace: DSpac_48746_noMsk_Column_VRT contains 6 histograms
# workspace: DSpac_48746_noMsk_Group_VRT contains 2 histograms
# Generated useRunLst: [48746]
# masktag: noMsk

# %% [markdown]
# ## Display all runs in useRunLst for a chosen pixel group
#
# Specify name of group at start of script. For cases where a group contains multiple histograms, can also specify histogram of choice.

# %%
import matplotlib.pyplot as plt

# %matplotlib widget
runLst = useRunLst

focGp='Group'
histogram=1
off=0.05 #will offset successive runs by this amount vertically


figTitle = f'all runs in useRunLst for group {focGp}'
fig, ax = plt.subplots()
for i,run in enumerate(runLst):


    wsName = f'DSpac_{run}_{mskTag}_{focGp}_VRT'
    ws = mtd[wsName]

    x = ws.readX(histogram)
    y = ws.readY(histogram)+i*off
    ax.plot(x[0:-1],y,label=f'{run}') #This is a hack because CTPD is crashing for unknown reason.

    
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(sPrm['focGroupLst'])
for gpNo, focGrp in enumerate(sPrm['focGroupLst']):
    print(sPrm['focGroupDMin'][gpNo])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_215566/2116917904.py in <module>
# ----> 1 print(sPrm['focGroupLst'])
#       2 for gpNo, focGrp in enumerate(sPrm['focGroupLst']):
#       3     print(sPrm['focGroupDMin'][gpNo])
#
# NameError: name 'sPrm' is not defined

# %% [markdown]
# ## Or display all groups for a chosen run
#
# Available runs are contained in `useRunLst`. During reduction, one of two masks type can be applied or no masks at all. The nature of the mask applied is stored in the name of the workspace.
#
# Correspondingly, it is necessary to specify

# %%
useRunLst
# Out:
# [48746, 57250, 57256]

# %%
import matplotlib.pyplot as plt

# %matplotlib widget

focGpLst=['All','Column','Group']
runIndx = 2
mskTag = 'noMsk'

runLst = useRunLst
off = 0.2 #set to offset successive groups
figTitle = f'all groups for run {runLst[runIndx]}'
fig, ax = plt.subplots()
for i,focGp in enumerate(focGpLst):
    wsName = f'DSpac_{runLst[runIndx]}_{mskTag}_{focGp}_VRT'
    ws = mtd[wsName]
    kk=0
    x = ws.readX(kk)
    y = ws.readY(kk)+i*off
    ax.plot(x[0:-1],y,label=f'{focGp}') #This is a hack because CTPD is crashing for unknown reason.

    
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_247218/2060074867.py in <module>
#       9 runLst = useRunLst
#      10 off = 0.2 #set to offset successive groups
# ---> 11 figTitle = f'all groups for run {runLst[runIndx]}'
#      12 fig, ax = plt.subplots()
#      13 for i,focGp in enumerate(focGpLst):
#
# IndexError: list index out of range

# %% [markdown]
# ## Attempt to subtract background before saving GSAS files
#
# My first attempt is to copy Clemens Prescher's background subtraction script. Looks like it will work with a simple copy/paste

# %%
# import numpy as np

def smooth_bruckner(y, smooth_points, iterations):
    y_original = y
    N_data = y.size
    N = smooth_points
    N_float = float(N)
    y = np.empty(N_data + N + N)

    y[0:N].fill(y_original[0])
    y[N:N + N_data] = y_original[0:N_data]
    y[N + N_data:N_data + N + N].fill(y_original[-1])

    y_avg = np.average(y)
    y_min = np.min(y)

    y_c = y_avg + 2. * (y_avg - y_min)
    y[y > y_c] = y_c

    window_size = N_float*2+1


    for j in range(0, iterations):
        window_avg = np.average(y[0: 2*N + 1])
        for i in range(N, N_data - 1 - N - 1):
            if y[i]>window_avg:
                y_new = window_avg
                #updating central value in average (first bracket)
                #and shifting average by one index (second bracket)
                window_avg += ((window_avg-y[i]) + (y[i+N+1]-y[i - N]))/window_size
                y[i] = y_new
            else:
                #shifting average by one index
                window_avg += (y[i+N+1]-y[i - N])/window_size
    return y[N:N + N_data]

def extract_background(x, y, smooth_width=0.1, iterations=50, cheb_order=50):
    """
    Performs a background subtraction using bruckner smoothing and a chebyshev polynomial.
    Standard parameters are found to be optimal for synchrotron XRD.
    :param x: x-data of pattern
    :param y: y-data of pattern
    :param smooth_width: width of the window in x-units used for bruckner smoothing
    :param iterations: number of iterations for the bruckner smoothing
    :param cheb_order: order of the fitted chebyshev polynomial
    :return: vector of extracted y background
    """
    smooth_points = int((float(smooth_width) / (x[1] - x[0])))

    y_smooth = smooth_bruckner(y, abs(smooth_points), iterations)
    # get cheb input parameters
    x_cheb = 2. * (x - x[0]) / (x[-1] - x[0]) - 1.
    cheb_parameters = np.polynomial.chebyshev.chebfit(x_cheb,
                                                      y_smooth,
                                                      cheb_order)

    return np.polynomial.chebyshev.chebval(x_cheb, cheb_parameters)

#get data
plt.close(fig)
focGpLst=['Gp01','Gp02']
useRunIndx = 0
off = 0.2

#plot results
figTitle = f'Dioptas background fit for {useRunLst[useRunIndx]}'
fig, ax = plt.subplots()
for i,focGp in enumerate(focGpLst):
    wsName = f'DSpac_{useRunLst[useRunIndx]}_{mskTag}_{focGp}_VRT'
    ws = mtd[wsName]
    x = ws.readX(0)
    y = ws.readY(0)

    #fit background
    b = extract_background(x[0:-1],y,smooth_width=0.4,iterations=50,cheb_order=48)

    # print(len(b),len(x))

    ax.plot(x[0:-1],y+i*off,label=f'{useRunLst[useRunIndx]}') #This is a hack because CTPD is crashing for unknown reason.
    ax.plot(x[0:-1],b+i*off,label='bgnd')
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Try using ClipPeaks to fit background...
#
# ### First attempt
#
# Initial pass looks promising, but it is being pulled off by the large sample peaks.
#
# ### Second attempt:
#
# Introduced some pre-processing to remove peaks first and then running `ClipPeaks`. This looks promising, but `FindPeaks` isn't fully reliable. It can miss some peaks that seem to have quite different FWHM from majority of peaks.
#
# ### Third attempt
#
# Allow two passes of pre-processing where output of first pass is input to second pass and where second pass uses a different FWHM.
#
# This didn't seem to help
#
# ### Where to now?
#
# `FindPeaks` is just not doing what I need.It works some of the time, but there seem to always be one or two peaks that get missed for non-obvious reasons. It is also highly sensistive to FWHM input, which is specified in No. of bins. changing FWHM by +/- 1 is enough to dramatically change the found peaks behaviour.
#
# So, now I'm wondering if there is an alternative way to find and remove peaks?

# %%
#select a run to work on 
import numpy as np

config.setLogLevel(0, quiet=True)

runIndx=1
focGpIndx=0

fwhm1 = 10
fwhm2 = 5

#pre-process data

#check no foundPks workspace already exists. If so, delete it

try:
    DeleteWorkspace(Workspace=foundPks)
    print('deleted existing foundPks ws')
except:
    pass

#get input data

ws = mtd[f'DSpac_{useRunLst[runIndx]}_{mskTag}_{focGpLst[focGpIndx]}_VRT']
x = ws.readX(0)
y = ws.readY(0)

#
# First pass
#

foundPks=FindPeaks(InputWorkspace=f'DSpac_{useRunLst[runIndx]}_{mskTag}_{focGpLst[focGpIndx]}_VRT',
        FWHM=fwhm1,
        PeakFunction='Gaussian',
        BackgroundType='Quadratic',
        PeaksList='pkList',
        HighBackground=True)
df = pd.DataFrame(foundPks.toDict())
#print(df)

pksy = np.zeros(len(y)) #array to put found peak intensities
nPks = foundPks.rowCount()
for i in range(nPks):
    h = foundPks.row(i)['height']
    c = foundPks.row(i)['centre']
    FWHM = foundPks.row(i)['width']
    sig = FWHM/(2*np.sqrt(2*np.log(2)))
    
    #messy part below handles weird behaviour of FindPeaks that puts
    #two identical peaks on top of one another...
    
    if i != 0:
        gapToPrev = np.abs(c-foundPks.row(i-1)['centre'])
        if gapToPrev>FWHM:
            for j in range(len(x)-1):
                xval = (x[j]+x[j+1])/2 #mid point of bin
                pksy[j]=pksy[j]+h*np.exp(-0.5*((xval-c)/sig)**2)
        else:
            pass
    if i == 0:
        for j in range(len(x)-1):
                xval = (x[j]+x[j+1])/2 #mid point of bin
                pksy[j]=pksy[j]+h*np.exp(-0.5*((xval-c)/sig)**2)
        
#subtract fitted peaks from y data
yMinusPks1 = y-pksy

#plot results
figTitle = f'First pass subtracting peaks from {useRunLst[runIndx]}'
fig, ax = plt.subplots()
ax.plot(x[0:-1],y,label=f'{useRunLst[runIndx]}') #This is a hack because CTPD is crashing for unknown reason.
ax.plot(x[0:-1],yMinusPks1,label='Peaks Subtracted')
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')

#
#Second pass
#

#need to put output of first pass into a mantid workspace to use FindPeaks
CreateWorkspace(OutputWorkspace='FirstPkRem',
                DataX=x,
                DataY=yMinusPks)


foundPks=FindPeaks(InputWorkspace='FirstPkRem',
        FWHM=fwhm2,
        PeakFunction='Gaussian',
        BackgroundType='Quadratic',
        PeaksList='pkList',
        HighBackground=True)
df = pd.DataFrame(foundPks.toDict())
print(df)

pksy = np.zeros(len(yMinusPks)) #array to put found peak intensities
nPks = foundPks.rowCount()
for i in range(nPks):
    h = foundPks.row(i)['height']
    c = foundPks.row(i)['centre']
    FWHM = foundPks.row(i)['width']
    sig = FWHM/(2*np.sqrt(2*np.log(2)))
    
    #messy part below handles weird behaviour of FindPeaks that puts
    #two identical peaks on top of one another...
    
    if i != 0:
        gapToPrev = np.abs(c-foundPks.row(i-1)['centre'])
        if gapToPrev>FWHM:
            for j in range(len(x)-1):
                xval = (x[j]+x[j+1])/2 #mid point of bin
                pksy[j]=pksy[j]+h*np.exp(-0.5*((xval-c)/sig)**2)
        else:
            pass
    if i == 0:
        for j in range(len(x)-1):
                xval = (x[j]+x[j+1])/2 #mid point of bin
                pksy[j]=pksy[j]+h*np.exp(-0.5*((xval-c)/sig)**2)
        
#subtract fitted peaks from y data
yMinusPks2 = yMinusPks1-pksy

#plot results
figTitle = f'Second pass subtracting peaks from {useRunLst[runIndx]}'
fig, ax = plt.subplots()
ax.plot(x[0:-1],y,label=f'{useRunLst[runIndx]}') #This is a hack because CTPD is crashing for unknown reason.
ax.plot(x[0:-1],yMinusPks2,label='Peaks Subtracted')
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# deleted existing foundPks ws
# Empty DataFrame
# Columns: [spectrum, centre, width, height, backgroundintercept, backgroundslope, A2, chi2]
# Index: []
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Exploring some scipy algorithms to find peaks...

# %%
from scipy.signal import find_peaks
#get input data

focGpIndx=0

ws = mtd[f'DSpac_{useRunLst[useRunIndx]}_{mskTag}_{focGpLst[focGpIndx]}_VRT']
x = ws.readX(0)
y = ws.readY(0)
yin = np.array(y)

a,props = find_peaks(yin, 
                 height=0,
                 width=5,
                 prominence=0.02)
print(f'Found {len(a)} peaks found at: {x[a]}')

print(props.keys())
# for i in range(len(a)):
#     width=props["widths"][i]
#     print(f'peak {i} width {width}')

figTitle = f'scipy find_peaks on {useRunLst[runIndx]}'
fig, ax = plt.subplots()
ax.plot(x[0:-1],y,label=f'{useRunLst[runIndx]}')

#
# Run through list of peaks and print/plot useful things
#
for i in range(len(a)):
    width=props["widths"][i]
    pkIndx = a[i]
    print(f'peak {i} position: {x[pkIndx]:.3f} width {width:.3f}')
    #print(f'width divided by 2: {int(width/2)}')
    #print(f'min indx = {pkIndx-int(width/2)} max indx= {a[i]+int(width/2)}')
    ax.plot(x[a[i]],y[a[i]],label='scipy.find_peaks positions',
            marker='o',
            color='red',
            linestyle='none')
    pkRng=range(pkIndx-int(width/2),pkIndx+int(width/2))
    ax.plot(x[pkRng],y[pkRng],
           marker='o',
           color='green',
           linestyle='none')
        
ax.set_title(figTitle)
#plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# Found 10 peaks found at: [0.92454415 0.96514593 1.13365122 1.17518503 1.23911711 1.35846197
#  1.60202861 1.85187429 1.98013451 2.28437697]
# dict_keys(['peak_heights', 'prominences', 'left_bases', 'right_bases', 'widths', 'width_heights', 'left_ips', 'right_ips'])
# peak 0 position: 0.925 width 10.040
# peak 1 position: 0.965 width 11.006
# peak 2 position: 1.134 width 11.049
# peak 3 position: 1.175 width 6.725
# peak 4 position: 1.239 width 32.648
# peak 5 position: 1.358 width 87.792
# peak 6 position: 1.602 width 11.249
# peak 7 position: 1.852 width 10.391
# peak 8 position: 1.980 width 15.326
# peak 9 position: 2.284 width 8.132
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close(fig)

# %%
def smooth(data, order):
    # This smooths data based on linear weigthed average around
    # point i for example for an order of 7 the i point is
    # weighted 4, i=/- 1 weighted 3, i+/-2 weighted 2 and i+/-3
    # weighted 1 this input is only the y values
    sm = np.zeros(len(data))
    factor = order / 2 + 1

    for i in range(len(data)):
        temp = 0
        ave = 0
        for r in range(max(0, i - int(order / 2)),
                       min(i + int(order / 2), len(data) - 1) + 1):
            temp = temp + (factor - abs(r - i)) * data[r]
            ave = ave + factor - abs(r - i)
        sm[i] = temp / ave

    return sm

def LLS_transformation(input):
    # this transforms data to be more sensitive to weak peaks. The
    # function is reversed by the Inv_LLS function below
    out = np.log(np.log((input + 1)**0.5 + 1) + 1)

    return out

def Inv_LLS_transformation(input):
    # See Function LLS function above
    out = (np.exp(np.exp(input) - 1) - 1)**2 - 1

    return out


def peak_clip(data, win=30, decrease=True, LLS=True, smooth_window=0):
    start_data = np.copy(data)

    window = win

    if smooth_window > 0:
        data = smooth(data, smooth_window)

    if LLS:
        data = LLS_transformation(data)

    temp = data.copy()

    if decrease:
        scan = list(range(window + 1, 0, -1))
    else:
        scan = list(range(1, window + 1))

    for w in scan:
        for i in range(len(temp)):
            if i < w or i > (len(temp) - w - 1):
                continue
            else:
                win_array = temp[i - w:i + w + 1].copy()
                win_array_reversed = win_array[::-1]
                average = (win_array + win_array_reversed) / 2
                temp[i] = np.min(average[:int(len(average) / 2)])

    if LLS:
        temp = Inv_LLS_transformation(temp)


    index = np.where((start_data - temp) == min(start_data - temp))[0][0]
    output = temp * (start_data[index] / temp[index])

    return output


#clip peaks
b = peak_clip(yMinusPks2,win=4, decrease=False, LLS=False, smooth_window=0)+0.005

#plot results
figTitle = f'Clip Peaks background fit for {useRunLst[1]}'
fig, ax = plt.subplots()
ax.plot(x[0:-1],y,label=f'{useRunLst[1]}') #This is a hack because CTPD is crashing for unknown reason.
ax.plot(x[0:-1],b,label='bgnd')
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ymb = y-b

#plot results
figTitle = f'Background subtracted data for {useRunLst[1]}'
fig, ax = plt.subplots()
ax.plot(x[0:-1],ymb,label=f'{useRunLst[1]}') #This is a hack because CTPD is crashing for unknown reason.
ax.set_title(figTitle)
#plt.xlim(0.9,2.1)
#plt.ylim(-0.3,3)
plt.legend()
plt.xlabel('d-spacing, d (Ang)')
plt.ylabel('Arb. Intensity')
# Out:
# Text(0, 0.5, 'Arb. Intensity')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Generate GSAS files for all runs in useRunLst for a chosen group

# %%
import json

focGpLst=['Gp01','Gp02']
dispGp = 1

runLst = useRunLst

focGp=focGpLst[dispGp]

for i,run in enumerate(runLst):

    wsName = f'DSpac_{run}_{mskTag}_{focGp}_VRT'

    #get instrument, state parameters and run parameters and store in single dictionary
    allPrm = {}
    for key,value in iPrm.__dict__.items():
        if key[0:2] != '__':
            allPrm[key]=value

    sPrm,error=DAC.getStatePrm(int(run),'before')
    allPrm.update(sPrm)

    rPrm = DAC.initPrm(int(run),case='before')
    rPrm['maskFileName']=maskName.value #TODO: allow for different masks for different runs
    allPrm.update(rPrm)

    ConvertUnits(InputWorkspace=wsName,
                 OutputWorkspace='gsasOut',
                 Target='TOF')

    SaveGSS(InputWorkspace='gsasOut',
            Filename=allPrm['gsasFileLoc']+f'gsas2/{focGp}/snap{run}_{focGp}.gss',
            Bank=1,
            Format='SLOG',
            Append=False, 
            MultiplyByBinWidth=True,
            UserSpecifiedGSASHeader=f'run: {run}')

    print(f'wrote: {allPrm["gsasFileLoc"]}gsas2/{focGp}/snap{run}_{focGp}.gss')
    print(f'wrote: {allPrm["gsasFileLoc"]}gsas2/{focGp}/snap{run}_{focGp}.json')

    redPrmFile = allPrm['gsasFileLoc']+f'gsas2/{focGp}/snap{run}_{focGp}.json'    
    with open(redPrmFile, "w") as outfile:
        json.dump(allPrm, outfile)

        
DeleteWorkspace(Workspace='gsasOut')
print(f'Completed writing gsas files for group: {focGp}')
# Out:
# wrote: /SNS/SNAP/IPTS-24179/shared/test/reduced/gsas2/Gp02/snap48705_Gp02.gss
# wrote: /SNS/SNAP/IPTS-24179/shared/test/reduced/gsas2/Gp02/snap48705_Gp02.json
# Completed writing gsas files for group: Gp02

# %%
import matplotlib.pyplot as plt

# %matplotlib widget

def showData(run2plot,focGroupLst,UseSpec_CBG):

    #UseSpec_RBG is a list of names like 'Col 3' etc. need to extract the number
    #there must be a more pythonic way :( 
    b = []
    for x in UseSpec_CBG:
        for y in x.split():
            if y.isdigit():
                b.append(int(y)-1)
    #print('Trying to plot these spectra: ',b)

    wsName = f'DSpac_{run2plot}_binMsk_Column_VRT'
    figTitle = f'Run: {run2plot} Group: {focGroupLst}'
    #ConvertToPointData(InputWorkspace=wsName,OutputWorkspace='pts')
    ws = mtd[wsName]
    #
    # Plotting code
    #
    fig, ax = plt.subplots()
    for kk in b:
        x = ws.readX(kk)
        y = ws.readY(kk)
        ax.plot(x[0:-1],y,label=f'Det. Column {kk+1}') #This is a hack because CTPD is crashing for unknown reason.
    ax.set_title(figTitle)
    plt.xlim(0.9,2.1)
    plt.ylim(-0.3,3)
    plt.legend()
    plt.xlabel('d-spacing, d (Ang)')
    plt.ylabel('Arb. Intensity')
    return fig


#create checkbuttongroup for pixel groups

# UseSpec_CBG = pn.widgets.CheckButtonGroup(name='Available Groups',
#                                           value=["A"],
#                                           options=["A","B"]

focGroupLst_RBG = pn.widgets.RadioButtonGroup(name='Available Focused Groups',
                                              value='Columns',
                                              options=['All','Bank','Columns'])

#separately define group names for groups. This will be used to allow selection between them, and for legend



UseSpec_CBG = pn.widgets.CheckButtonGroup(name='Available Groups',
                                              value=['Col 3','Col 4'],
                                              options=['Col 1',
                                                       'Col 2',
                                                       'Col 3',
                                                       'Col 4',
                                                       'Col 5',
                                                       'Col 6'],
                                          orientation='vertical')
run2plot=useRunLst[0] 


dispFnCall = pn.bind(showData,run2plot,focGroupLst_RBG,UseSpec_CBG)
# fig, ax = plt.subplots()
# disp = pn.pane.Matplotlib(fig)

col = pn.Column(focGroupLst_RBG,UseSpec_CBG)
plotPanel = pn.Row(col,dispFnCall)
plotPanel
# Out:
# Row
#     [0] Column
#         [0] RadioButtonGroup(name='Available Focused G..., options=['All', 'Bank', ...], value='Columns')
#         [1] CheckButtonGroup(name='Available Groups', options=['Col 1', 'Col 2', ...], orientation='vertical', value=['Col 3', 'Col 4'])
#     [1] ParamFunction(function)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
